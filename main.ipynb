# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import re
import random
import os
# Out:
# /Users/william/anaconda3/envs/machine-poet/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Model

# %% [markdown]
# # v1 - Current
# * One layer of LSTM
# * Non-batch train
# * Problems
#     * Too many small ops, slowing down trainning speed, hard for GPU to process

# %% [markdown]
# ## Dataset Initialization

# %%
# Dataset
embed = hub.Module("https://tfhub.dev/google/nnlm-en-dim50/1")
string2idtable = tf.contrib.lookup.index_table_from_file(vocabulary_file="vocabulary-shakespeare-Copy1.txt", num_oov_buckets=0)
id2stringtabel = tf.contrib.lookup.index_to_string_table_from_file(vocabulary_file="vocabulary-shakespeare-Copy1.txt")
def _insertSpace(sentence):
    sentence = sentence.decode()
    sentence = sentence.lower()
    sentence = re.sub(r'([\W\d])', r' \1 ', sentence)
    return sentence
def _getLabel(sentence):
    splited = tf.string_split([sentence]).values
    sentence = splited
    sentence = sentence[0:-1]
    ids = string2idtable.lookup(splited)
    ids = tf.one_hot(ids, 11405)
    return sentence, ids
filenames = ["poems/shakespeare/sonnets.txt"]
dataset = tf.data.TextLineDataset(filenames)
dataset = dataset.map(lambda sentence: tf.py_func(_insertSpace, [sentence], tf.string))
dataset = dataset.map(_getLabel)
dataset = dataset.shuffle(buffer_size=10000)
# dataset = dataset.batch(4)
dataset = dataset.repeat()
iterator = dataset.make_initializable_iterator()
next_poem = iterator.get_next()
# Out:
# INFO:tensorflow:Using /var/folders/qz/dx3zfgtj2lqf70kv8b90s8wr0000gp/T/tfhub_modules to cache modules.
# INFO:tensorflow:Initialize variable module/embeddings/part_0:0 from checkpoint b'/var/folders/qz/dx3zfgtj2lqf70kv8b90s8wr0000gp/T/tfhub_modules/7f07056e3a4c9f125d5bd920ef3883605d8556a8/variables/variables' with embeddings

# %% [markdown]
# ## Model initialization and Graph building

# %%
# with tf.Graph().as_default():
# Graph
# Variables
with tf.variable_scope("model_v1", reuse=tf.AUTO_REUSE):
    softmax_w = tf.get_variable("softmax_w", shape=[400, 11405], initializer=tf.random_normal_initializer)
    softmax_b = tf.get_variable("softmax_b", shape=[1, 11405], initializer=tf.random_normal_initializer)

    # TODO Use tuple for state
    lstm = tf.contrib.rnn.LSTMCell(400, state_is_tuple=False, initializer=tf.random_normal_initializer, reuse=tf.AUTO_REUSE, name="LSTM1")

# Model
sentence, label = next_poem
sentence = embed(sentence)
sentence = tf.concat([tf.zeros([1, 50]), sentence], 0, name="Insert_X_0")

state = tf.placeholder(shape=[1, lstm.state_size], dtype=tf.float32, name="Previous_State")

# Input and Label
x = tf.placeholder(shape=[1, 50], dtype=tf.float32, name="Input_Word")
y = tf.placeholder(shape=[1, 11405], dtype=tf.int32, name="Target_Word")

input_word = tf.reshape(x, [1, 50])
output, out_state = lstm(input_word, state)
logits = tf.add(tf.matmul(output, softmax_w), softmax_b)
possibility = tf.nn.softmax(logits=logits, name="Possibilities")
word_index = tf.argmax(possibility, axis=-1, name="Predict_Word_index")
word = id2stringtabel.lookup(word_index)
loss_op = tf.losses.softmax_cross_entropy(onehot_labels=y, logits=logits)
tf.summary.scalar(name="loss", tensor=loss_op)
merged = tf.summary.merge_all()

# Train Ops
with tf.variable_scope("model_v1"):
    optimizer = tf.train.AdamOptimizer()
train_op = optimizer.minimize(loss_op)

# Global step as variable for persistent tensorboard output
# with tf.variable_scope("model_v1"):
#     global_step = tf.get_variable("Global_Steps", [], initializer=tf.ones_initializer, dtype=tf.int64)

# Variables saver
saver = tf.train.Saver()

sess = tf.Session()
# with tf.Session() as sess:
try:
    saver.restore(sess, "tmp/model/model_v1/model.ckpt")
except tf.errors.NotFoundError:
    pass
sess.run(tf.global_variables_initializer())
tf.tables_initializer().run(session=sess)
sess.run(iterator.initializer)

# Trainning log
# TODO writer = tf.summary.FileWriter("tmp/log/"+Modelv1+embedding_version, sess.graph)
writer = tf.summary.FileWriter("tmp/log/model_v1/", sess.graph)

# TODO Retrieve existing g_steps
# g_steps = global_step.eval(session=sess)

g_steps = 1
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.LSTMCell object at 0x11e98b2b0>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# INFO:tensorflow:Restoring parameters from tmp/model/model_v1/model.ckpt

# %% [markdown]
# ## Train Module

# %%
with tf.variable_scope("model_v1"):
    total_poems = 1000
    for _ in range(total_poems):
        wordsVec, targets = sess.run([sentence, label])
        # TODO How to Access timestep?
        # Initial
        _, pre_state = sess.run([output, out_state], feed_dict={x: [wordsVec[0]], y: [targets[0]], state: np.zeros([1, lstm.state_size], dtype=float)})
        for i in range(1, wordsVec.shape[0]):
            # g_steps = global_step.eval(session=sess)

            _, pre_state, loss, summary, out = sess.run([train_op, out_state, loss_op, merged, word], feed_dict={x: [wordsVec[i]], y: [targets[i]], state: pre_state})
            writer.add_summary(summary, global_step=g_steps)
            # TODO Should Average loss
            tf.logging.log_every_n(tf.logging.INFO, "Loss: %s | local step: %s | global step: %s | Output: %s", 100, loss, i, g_steps, out)
            if g_steps%2000 == 0:
                # Store Variables Every 2000 times
                saver.save(sess, "tmp/model/model_v1/model.ckpt")
            # global_step += 1 
            g_steps += 1
    print("Trainning times: ", total_poems)
    saver.save(sess, "tmp/model/model_v1/model.ckpt")
# Out:
# INFO:tensorflow:Loss: 14.2019615 | local step: 1 | global step: 1 | Output: [b'bear']
# INFO:tensorflow:Loss: 51.269737 | local step: 101 | global step: 101 | Output: [b'myrtle']
# INFO:tensorflow:Loss: 33.284767 | local step: 38 | global step: 201 | Output: [b'orchestra']
# INFO:tensorflow:Loss: 19.081789 | local step: 138 | global step: 301 | Output: [b'reality']
# INFO:tensorflow:Loss: 30.319763 | local step: 69 | global step: 401 | Output: [b'join']
# INFO:tensorflow:Loss: 40.45078 | local step: 7 | global step: 501 | Output: [b'freezings']
# INFO:tensorflow:Loss: 39.19845 | local step: 107 | global step: 601 | Output: [b'scared']
# INFO:tensorflow:Loss: 26.631638 | local step: 51 | global step: 701 | Output: [b'simply']
# INFO:tensorflow:Loss: 29.239092 | local step: 151 | global step: 801 | Output: [b'chrysler']
# INFO:tensorflow:Loss: 40.369682 | local step: 100 | global step: 901 | Output: [b'explore']
# INFO:tensorflow:Loss: 27.902224 | local step: 43 | global step: 1001 | Output: [b'agriculture']
# INFO:tensorflow:Loss: 30.239311 | local step: 143 | global step: 1101 | Output: [b'helmet']
# INFO:tensorflow:Loss: 28.718214 | local step: 89 | global step: 1201 | Output: [b'strongly']
# INFO:tensorflow:Loss: 30.789392 | local step: 26 | global step: 1301 | Output: [b'swim']
# INFO:tensorflow:Loss: 28.664217 | local step: 126 | global step: 1401 | Output: [b'residents']
# INFO:tensorflow:Loss: 39.281082 | local step: 67 | global step: 1501 | Output: [b'towns']
# INFO:tensorflow:Loss: 35.845272 | local step: 167 | global step: 1601 | Output: [b'plots']
# INFO:tensorflow:Loss: 31.05381 | local step: 98 | global step: 1701 | Output: [b'shall']
# INFO:tensorflow:Loss: 33.111668 | local step: 44 | global step: 1801 | Output: [b'signs']
# INFO:tensorflow:Loss: 22.295826 | local step: 144 | global step: 1901 | Output: [b'oops']
# INFO:tensorflow:Loss: 36.070766 | local step: 94 | global step: 2001 | Output: [b'fossil']
# INFO:tensorflow:Loss: 27.347708 | local step: 35 | global step: 2101 | Output: [b'recently']
# INFO:tensorflow:Loss: 34.235146 | local step: 135 | global step: 2201 | Output: [b'resolved']
# INFO:tensorflow:Loss: 36.943695 | local step: 65 | global step: 2301 | Output: [b'workings']
# INFO:tensorflow:Loss: 40.283432 | local step: 16 | global step: 2401 | Output: [b'wa']
# INFO:tensorflow:Loss: 42.344738 | local step: 116 | global step: 2501 | Output: [b'puzzle']
# INFO:tensorflow:Loss: 49.646717 | local step: 74 | global step: 2601 | Output: [b'every']
# INFO:tensorflow:Loss: 18.673578 | local step: 27 | global step: 2701 | Output: [b'paragraph']
# INFO:tensorflow:Loss: 51.329285 | local step: 127 | global step: 2801 | Output: [b'orchestra']
# INFO:tensorflow:Loss: 20.757313 | local step: 80 | global step: 2901 | Output: [b'rocks']
# INFO:tensorflow:Loss: 41.83361 | local step: 41 | global step: 3001 | Output: [b'dispatch']
# INFO:tensorflow:Loss: 30.310549 | local step: 141 | global step: 3101 | Output: [b'give']
# INFO:tensorflow:Loss: 48.59634 | local step: 95 | global step: 3201 | Output: [b'panama']
# INFO:tensorflow:Loss: 25.662973 | local step: 39 | global step: 3301 | Output: [b'conflict']
# INFO:tensorflow:Loss: 40.538055 | local step: 139 | global step: 3401 | Output: [b'purpose']
# INFO:tensorflow:Loss: 26.61583 | local step: 95 | global step: 3501 | Output: [b'bargains']
# INFO:tensorflow:Loss: 31.392199 | local step: 25 | global step: 3601 | Output: [b'desktops']
# INFO:tensorflow:Loss: 27.324854 | local step: 125 | global step: 3701 | Output: [b'prospect']
# INFO:tensorflow:Loss: 37.597065 | local step: 64 | global step: 3801 | Output: [b'blogging']
# INFO:tensorflow:Loss: 34.61646 | local step: 164 | global step: 3901 | Output: [b'pull']
# INFO:tensorflow:Loss: 22.40429 | local step: 99 | global step: 4001 | Output: [b'oliver']
# INFO:tensorflow:Loss: 16.567911 | local step: 43 | global step: 4101 | Output: [b'officially']
# INFO:tensorflow:Loss: 20.84468 | local step: 143 | global step: 4201 | Output: [b'bestow']
# INFO:tensorflow:Loss: 16.08647 | local step: 94 | global step: 4301 | Output: [b'remembrance']
# INFO:tensorflow:Loss: 41.91319 | local step: 49 | global step: 4401 | Output: [b'comparison']
# INFO:tensorflow:Loss: 21.086031 | local step: 149 | global step: 4501 | Output: [b'breast']
# INFO:tensorflow:Loss: 24.643185 | local step: 99 | global step: 4601 | Output: [b'caught']
# INFO:tensorflow:Loss: 21.436373 | local step: 50 | global step: 4701 | Output: [b'contests']
# INFO:tensorflow:Loss: 11.646288 | local step: 3 | global step: 4801 | Output: [b'quit']
# INFO:tensorflow:Loss: 30.552063 | local step: 103 | global step: 4901 | Output: [b'tale']
# INFO:tensorflow:Loss: 33.220413 | local step: 45 | global step: 5001 | Output: [b'towards']
# INFO:tensorflow:Loss: 13.900812 | local step: 1 | global step: 5101 | Output: [b'visible']
# INFO:tensorflow:Loss: 40.731262 | local step: 101 | global step: 5201 | Output: [b'reseller']
# INFO:tensorflow:Loss: 21.023762 | local step: 38 | global step: 5301 | Output: [b'entities']
# INFO:tensorflow:Loss: 22.7519 | local step: 138 | global step: 5401 | Output: [b'winning']
# INFO:tensorflow:Loss: 28.066975 | local step: 88 | global step: 5501 | Output: [b'lines']
# INFO:tensorflow:Loss: 31.32193 | local step: 33 | global step: 5601 | Output: [b'screensavers']
# INFO:tensorflow:Loss: 34.093067 | local step: 133 | global step: 5701 | Output: [b'eugene']
# INFO:tensorflow:Loss: 39.534565 | local step: 80 | global step: 5801 | Output: [b'delhi']
# INFO:tensorflow:Loss: 37.998096 | local step: 15 | global step: 5901 | Output: [b'holdings']
# INFO:tensorflow:Loss: 6.503197 | local step: 115 | global step: 6001 | Output: [b'recycling']
# INFO:tensorflow:Loss: 29.611023 | local step: 62 | global step: 6101 | Output: [b'cole']
# INFO:tensorflow:Loss: 23.13962 | local step: 21 | global step: 6201 | Output: [b'that']
# INFO:tensorflow:Loss: 32.503384 | local step: 121 | global step: 6301 | Output: [b'penguin']
# INFO:tensorflow:Loss: 33.941166 | local step: 72 | global step: 6401 | Output: [b'halt']
# INFO:tensorflow:Loss: 25.534096 | local step: 18 | global step: 6501 | Output: [b'adding']
# INFO:tensorflow:Loss: 19.2386 | local step: 118 | global step: 6601 | Output: [b'warren']
# INFO:tensorflow:Loss: 19.006958 | local step: 68 | global step: 6701 | Output: [b'trenches']
# INFO:tensorflow:Loss: 44.443462 | local step: 16 | global step: 6801 | Output: [b'exhibit']
# INFO:tensorflow:Loss: 32.477383 | local step: 116 | global step: 6901 | Output: [b'labour']
# INFO:tensorflow:Loss: 54.95557 | local step: 67 | global step: 7001 | Output: [b'or']
# INFO:tensorflow:Loss: 25.989134 | local step: 9 | global step: 7101 | Output: [b'craft']
# INFO:tensorflow:Loss: 41.66332 | local step: 109 | global step: 7201 | Output: [b'liable']
# INFO:tensorflow:Loss: 26.909632 | local step: 54 | global step: 7301 | Output: [b'jpeg']
# INFO:tensorflow:Loss: 15.013697 | local step: 7 | global step: 7401 | Output: [b'enlighten']
# INFO:tensorflow:Loss: 30.269907 | local step: 107 | global step: 7501 | Output: [b'bat']
# INFO:tensorflow:Loss: 35.297985 | local step: 55 | global step: 7601 | Output: [b'error']
# INFO:tensorflow:Loss: 9.500503 | local step: 11 | global step: 7701 | Output: [b'gather']
# INFO:tensorflow:Loss: 30.36647 | local step: 111 | global step: 7801 | Output: [b'stage']
# INFO:tensorflow:Loss: 24.400724 | local step: 47 | global step: 7901 | Output: [b'clip']
# INFO:tensorflow:Loss: 16.94071 | local step: 147 | global step: 8001 | Output: [b'topics']
# INFO:tensorflow:Loss: 31.255316 | local step: 96 | global step: 8101 | Output: [b'dave']
# INFO:tensorflow:Loss: 27.604628 | local step: 44 | global step: 8201 | Output: [b'signal']
# INFO:tensorflow:Loss: 12.178989 | local step: 144 | global step: 8301 | Output: [b'engrafted']
# INFO:tensorflow:Loss: 27.96003 | local step: 89 | global step: 8401 | Output: [b'cho']
# INFO:tensorflow:Loss: 18.870756 | local step: 42 | global step: 8501 | Output: [b'v']
# INFO:tensorflow:Loss: 23.677517 | local step: 142 | global step: 8601 | Output: [b'well']
# INFO:tensorflow:Loss: 32.661427 | local step: 91 | global step: 8701 | Output: [b'croatia']
# INFO:tensorflow:Loss: 15.737619 | local step: 48 | global step: 8801 | Output: [b'widespread']
# INFO:tensorflow:Loss: 26.19538 | local step: 148 | global step: 8901 | Output: [b'cancell']
# INFO:tensorflow:Loss: 16.266245 | local step: 100 | global step: 9001 | Output: [b'measured']
# INFO:tensorflow:Loss: 19.21498 | local step: 47 | global step: 9101 | Output: [b'corners']
# INFO:tensorflow:Loss: 18.631683 | local step: 147 | global step: 9201 | Output: [b'new']
# INFO:tensorflow:Loss: 37.362873 | local step: 94 | global step: 9301 | Output: [b'retain']
# INFO:tensorflow:Loss: 25.227264 | local step: 47 | global step: 9401 | Output: [b'sydney']
# INFO:tensorflow:Loss: 30.9148 | local step: 147 | global step: 9501 | Output: [b'nasa']
# INFO:tensorflow:Loss: 23.77866 | local step: 82 | global step: 9601 | Output: [b'quarter']
# INFO:tensorflow:Loss: 24.501148 | local step: 25 | global step: 9701 | Output: [b'remote']
# INFO:tensorflow:Loss: 27.66588 | local step: 125 | global step: 9801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 18.436596 | local step: 74 | global step: 9901 | Output: [b'thirty']
# INFO:tensorflow:Loss: 42.700558 | local step: 22 | global step: 10001 | Output: [b'homes']
# INFO:tensorflow:Loss: 24.051493 | local step: 122 | global step: 10101 | Output: [b'or']
# INFO:tensorflow:Loss: 15.395009 | local step: 62 | global step: 10201 | Output: [b'written']
# INFO:tensorflow:Loss: 26.65705 | local step: 162 | global step: 10301 | Output: [b'overthrow']
# INFO:tensorflow:Loss: 22.216682 | local step: 100 | global step: 10401 | Output: [b'current']
# INFO:tensorflow:Loss: 29.312162 | local step: 56 | global step: 10501 | Output: [b'maintenance']
# INFO:tensorflow:Loss: 10.190238 | local step: 3 | global step: 10601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 30.381691 | local step: 103 | global step: 10701 | Output: [b'coat']
# INFO:tensorflow:Loss: 25.021708 | local step: 48 | global step: 10801 | Output: [b'initially']
# INFO:tensorflow:Loss: 22.435474 | local step: 148 | global step: 10901 | Output: [b'maintained']
# INFO:tensorflow:Loss: 39.429634 | local step: 90 | global step: 11001 | Output: [b'hiding']
# INFO:tensorflow:Loss: 16.62576 | local step: 31 | global step: 11101 | Output: [b'hast']
# INFO:tensorflow:Loss: 26.058748 | local step: 131 | global step: 11201 | Output: [b'days']
# INFO:tensorflow:Loss: 10.548898 | local step: 76 | global step: 11301 | Output: [b'invitations']
# INFO:tensorflow:Loss: 37.325687 | local step: 19 | global step: 11401 | Output: [b'syndication']
# INFO:tensorflow:Loss: 14.706223 | local step: 119 | global step: 11501 | Output: [b'replace']
# INFO:tensorflow:Loss: 16.74637 | local step: 56 | global step: 11601 | Output: [b'seq']
# INFO:tensorflow:Loss: 10.813778 | local step: 1 | global step: 11701 | Output: [b"'"]
# INFO:tensorflow:Loss: 29.17637 | local step: 101 | global step: 11801 | Output: [b'simply']
# INFO:tensorflow:Loss: 12.119107 | local step: 40 | global step: 11901 | Output: [b'don']
# INFO:tensorflow:Loss: 16.763063 | local step: 140 | global step: 12001 | Output: [b'wouldst']
# INFO:tensorflow:Loss: 8.509884 | local step: 81 | global step: 12101 | Output: [b'odour']
# INFO:tensorflow:Loss: 0.05122096 | local step: 38 | global step: 12201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 18.678144 | local step: 138 | global step: 12301 | Output: [b'poll']
# INFO:tensorflow:Loss: 20.467646 | local step: 74 | global step: 12401 | Output: [b'mode']
# INFO:tensorflow:Loss: 9.715307 | local step: 10 | global step: 12501 | Output: [b'hong']
# INFO:tensorflow:Loss: 13.521886 | local step: 110 | global step: 12601 | Output: [b'i']
# INFO:tensorflow:Loss: 18.215857 | local step: 61 | global step: 12701 | Output: [b'to']
# INFO:tensorflow:Loss: 16.163609 | local step: 3 | global step: 12801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 17.31079 | local step: 103 | global step: 12901 | Output: [b',']
# INFO:tensorflow:Loss: 21.013786 | local step: 50 | global step: 13001 | Output: [b'mediterranean']
# INFO:tensorflow:Loss: 23.636362 | local step: 150 | global step: 13101 | Output: [b',']
# INFO:tensorflow:Loss: 11.656162 | local step: 93 | global step: 13201 | Output: [b'packets']
# INFO:tensorflow:Loss: 26.240173 | local step: 24 | global step: 13301 | Output: [b'!']
# INFO:tensorflow:Loss: 19.866951 | local step: 124 | global step: 13401 | Output: [b'was']
# INFO:tensorflow:Loss: 24.056053 | local step: 69 | global step: 13501 | Output: [b'alliance']
# INFO:tensorflow:Loss: 11.243425 | local step: 17 | global step: 13601 | Output: [b'the']
# INFO:tensorflow:Loss: 17.938051 | local step: 117 | global step: 13701 | Output: [b'chick']
# INFO:tensorflow:Loss: 16.849106 | local step: 48 | global step: 13801 | Output: [b'will']
# INFO:tensorflow:Loss: 21.081587 | local step: 148 | global step: 13901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 34.177086 | local step: 94 | global step: 14001 | Output: [b'professionals']
# INFO:tensorflow:Loss: 9.371916 | local step: 59 | global step: 14101 | Output: [b'oaths']
# INFO:tensorflow:Loss: 18.070515 | local step: 5 | global step: 14201 | Output: [b'implementation']
# INFO:tensorflow:Loss: 7.496614 | local step: 105 | global step: 14301 | Output: [b'me']
# INFO:tensorflow:Loss: 12.5488615 | local step: 65 | global step: 14401 | Output: [b'my']
# INFO:tensorflow:Loss: 3.7236614 | local step: 165 | global step: 14501 | Output: [b'the']
# INFO:tensorflow:Loss: 30.317184 | local step: 93 | global step: 14601 | Output: [b'lets']
# INFO:tensorflow:Loss: 12.297779 | local step: 44 | global step: 14701 | Output: [b'bar']
# INFO:tensorflow:Loss: 4.479311 | local step: 4 | global step: 14801 | Output: [b'to']
# INFO:tensorflow:Loss: 18.449326 | local step: 104 | global step: 14901 | Output: [b'consecutive']
# INFO:tensorflow:Loss: 0.03410108 | local step: 43 | global step: 15001 | Output: [b'my']
# INFO:tensorflow:Loss: 12.154441 | local step: 143 | global step: 15101 | Output: [b',']
# INFO:tensorflow:Loss: 6.0539865 | local step: 98 | global step: 15201 | Output: [b's']
# INFO:tensorflow:Loss: 18.97903 | local step: 57 | global step: 15301 | Output: [b'and']
# INFO:tensorflow:Loss: 20.44502 | local step: 157 | global step: 15401 | Output: [b'the']
# INFO:tensorflow:Loss: 8.833269 | local step: 98 | global step: 15501 | Output: [b'.']
# INFO:tensorflow:Loss: 15.796468 | local step: 29 | global step: 15601 | Output: [b'careful']
# INFO:tensorflow:Loss: 10.363263 | local step: 129 | global step: 15701 | Output: [b'you']
# INFO:tensorflow:Loss: 12.923917 | local step: 71 | global step: 15801 | Output: [b'i']
# INFO:tensorflow:Loss: 12.732393 | local step: 171 | global step: 15901 | Output: [b"'"]
# INFO:tensorflow:Loss: 5.7210093 | local step: 97 | global step: 16001 | Output: [b'me']
# INFO:tensorflow:Loss: 3.8753805 | local step: 39 | global step: 16101 | Output: [b'soon']
# INFO:tensorflow:Loss: 14.6555395 | local step: 139 | global step: 16201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 21.645237 | local step: 96 | global step: 16301 | Output: [b'which']
# INFO:tensorflow:Loss: 20.473934 | local step: 32 | global step: 16401 | Output: [b'constitution']
# INFO:tensorflow:Loss: 6.15483 | local step: 132 | global step: 16501 | Output: [b's']
# INFO:tensorflow:Loss: 11.793657 | local step: 94 | global step: 16601 | Output: [b'that']
# INFO:tensorflow:Loss: 12.199487 | local step: 32 | global step: 16701 | Output: [b'institution']
# INFO:tensorflow:Loss: 16.68986 | local step: 132 | global step: 16801 | Output: [b',']
# INFO:tensorflow:Loss: 12.219294 | local step: 86 | global step: 16901 | Output: [b'of']
# INFO:tensorflow:Loss: 13.026947 | local step: 43 | global step: 17001 | Output: [b'and']
# INFO:tensorflow:Loss: 13.414603 | local step: 143 | global step: 17101 | Output: [b'i']
# INFO:tensorflow:Loss: 20.396986 | local step: 82 | global step: 17201 | Output: [b',']
# INFO:tensorflow:Loss: 5.884941 | local step: 29 | global step: 17301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.8560524 | local step: 129 | global step: 17401 | Output: [b'true']
# INFO:tensorflow:Loss: 5.6772037 | local step: 86 | global step: 17501 | Output: [b',']
# INFO:tensorflow:Loss: 3.1390986 | local step: 34 | global step: 17601 | Output: [b'that']
# INFO:tensorflow:Loss: 4.8143654 | local step: 134 | global step: 17701 | Output: [b'the']
# INFO:tensorflow:Loss: 11.303325 | local step: 79 | global step: 17801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 8.724115 | local step: 22 | global step: 17901 | Output: [b';']
# INFO:tensorflow:Loss: 3.4283879 | local step: 122 | global step: 18001 | Output: [b'.']
# INFO:tensorflow:Loss: 1.0002851 | local step: 53 | global step: 18101 | Output: [b'that']
# INFO:tensorflow:Loss: 2.1743412 | local step: 5 | global step: 18201 | Output: [b',']
# INFO:tensorflow:Loss: 4.632498 | local step: 105 | global step: 18301 | Output: [b'thou']
# INFO:tensorflow:Loss: 11.480473 | local step: 37 | global step: 18401 | Output: [b"'"]
# INFO:tensorflow:Loss: 9.080132 | local step: 137 | global step: 18501 | Output: [b'that']
# INFO:tensorflow:Loss: 2.3166301 | local step: 77 | global step: 18601 | Output: [b'of']
# INFO:tensorflow:Loss: 10.449491 | local step: 30 | global step: 18701 | Output: [b',']
# INFO:tensorflow:Loss: 6.888339 | local step: 130 | global step: 18801 | Output: [b'd']
# INFO:tensorflow:Loss: 1.2440529 | local step: 69 | global step: 18901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 10.835291 | local step: 26 | global step: 19001 | Output: [b'too']
# INFO:tensorflow:Loss: 11.244032 | local step: 126 | global step: 19101 | Output: [b'of']
# INFO:tensorflow:Loss: 0.0 | local step: 70 | global step: 19201 | Output: [b"'"]
# INFO:tensorflow:Loss: 12.950619 | local step: 7 | global step: 19301 | Output: [b',']
# INFO:tensorflow:Loss: 8.517969 | local step: 107 | global step: 19401 | Output: [b'in']
# INFO:tensorflow:Loss: 4.4066873 | local step: 49 | global step: 19501 | Output: [b',']
# INFO:tensorflow:Loss: 3.7430418 | local step: 149 | global step: 19601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 6.966538 | local step: 90 | global step: 19701 | Output: [b'and']
# INFO:tensorflow:Loss: 8.944969 | local step: 31 | global step: 19801 | Output: [b',']
# INFO:tensorflow:Loss: 0.34529638 | local step: 131 | global step: 19901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.26327696 | local step: 72 | global step: 20001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 8.094733 | local step: 23 | global step: 20101 | Output: [b',']
# INFO:tensorflow:Loss: 5.655277 | local step: 123 | global step: 20201 | Output: [b',']
# INFO:tensorflow:Loss: 10.185683 | local step: 55 | global step: 20301 | Output: [b'of']
# INFO:tensorflow:Loss: 5.9258003 | local step: 155 | global step: 20401 | Output: [b',']
# INFO:tensorflow:Loss: 6.3214717 | local step: 98 | global step: 20501 | Output: [b',']
# INFO:tensorflow:Loss: 11.999683 | local step: 38 | global step: 20601 | Output: [b',']
# INFO:tensorflow:Loss: 5.3017607 | local step: 138 | global step: 20701 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.0650864 | local step: 97 | global step: 20801 | Output: [b"'"]
# INFO:tensorflow:Loss: 10.424561 | local step: 50 | global step: 20901 | Output: [b'and']
# INFO:tensorflow:Loss: 4.074853 | local step: 8 | global step: 21001 | Output: [b',']
# INFO:tensorflow:Loss: 8.674253 | local step: 108 | global step: 21101 | Output: [b"'"]
# INFO:tensorflow:Loss: 8.972932 | local step: 42 | global step: 21201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 12.432949 | local step: 142 | global step: 21301 | Output: [b'd']
# INFO:tensorflow:Loss: 11.765154 | local step: 86 | global step: 21401 | Output: [b'that']
# INFO:tensorflow:Loss: 0.50707996 | local step: 30 | global step: 21501 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.4481218 | local step: 130 | global step: 21601 | Output: [b'not']
# INFO:tensorflow:Loss: 11.980388 | local step: 77 | global step: 21701 | Output: [b'xxxendxxx']
# INFO:tensorflow:Loss: 4.743194 | local step: 15 | global step: 21801 | Output: [b';']
# INFO:tensorflow:Loss: 11.683814 | local step: 115 | global step: 21901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.4836202 | local step: 47 | global step: 22001 | Output: [b'and']
# INFO:tensorflow:Loss: 0.2337607 | local step: 10 | global step: 22101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.7262204 | local step: 110 | global step: 22201 | Output: [b',']
# INFO:tensorflow:Loss: 2.991923 | local step: 66 | global step: 22301 | Output: [b'for']
# INFO:tensorflow:Loss: 5.8492303 | local step: 166 | global step: 22401 | Output: [b"'"]
# INFO:tensorflow:Loss: 10.801159 | local step: 92 | global step: 22501 | Output: [b'to']
# INFO:tensorflow:Loss: 0.12088276 | local step: 35 | global step: 22601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.2721443 | local step: 135 | global step: 22701 | Output: [b'not']
# INFO:tensorflow:Loss: 4.4353323 | local step: 77 | global step: 22801 | Output: [b',']
# INFO:tensorflow:Loss: 0.0 | local step: 13 | global step: 22901 | Output: [b"'"]
# INFO:tensorflow:Loss: 7.9554343 | local step: 113 | global step: 23001 | Output: [b',']
# INFO:tensorflow:Loss: 0.35902715 | local step: 50 | global step: 23101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.6504276 | local step: 150 | global step: 23201 | Output: [b',']
# INFO:tensorflow:Loss: 10.86315 | local step: 99 | global step: 23301 | Output: [b'in']
# INFO:tensorflow:Loss: 1.5483546 | local step: 50 | global step: 23401 | Output: [b',']
# INFO:tensorflow:Loss: 7.243162 | local step: 150 | global step: 23501 | Output: [b',']
# INFO:tensorflow:Loss: 7.7366 | local step: 98 | global step: 23601 | Output: [b'the']
# INFO:tensorflow:Loss: 6.4496517 | local step: 40 | global step: 23701 | Output: [b'thou']
# INFO:tensorflow:Loss: 2.754653 | local step: 140 | global step: 23801 | Output: [b'thy']
# INFO:tensorflow:Loss: 11.827107 | local step: 93 | global step: 23901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.737424 | local step: 46 | global step: 24001 | Output: [b'no']
# INFO:tensorflow:Loss: 8.492324 | local step: 146 | global step: 24101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.902804 | local step: 78 | global step: 24201 | Output: [b'to']
# INFO:tensorflow:Loss: 3.6778753 | local step: 34 | global step: 24301 | Output: [b'my']
# INFO:tensorflow:Loss: 7.66961 | local step: 134 | global step: 24401 | Output: [b',']
# INFO:tensorflow:Loss: 3.8766649 | local step: 86 | global step: 24501 | Output: [b',']
# INFO:tensorflow:Loss: 5.177948 | local step: 33 | global step: 24601 | Output: [b'the']
# INFO:tensorflow:Loss: 7.407177 | local step: 133 | global step: 24701 | Output: [b'thou']
# INFO:tensorflow:Loss: 9.325662 | local step: 69 | global step: 24801 | Output: [b',']
# INFO:tensorflow:Loss: 3.455419 | local step: 15 | global step: 24901 | Output: [b'.']
# INFO:tensorflow:Loss: 4.2223606 | local step: 115 | global step: 25001 | Output: [b',']
# INFO:tensorflow:Loss: 3.974837 | local step: 57 | global step: 25101 | Output: [b"'"]
# INFO:tensorflow:Loss: 6.6803246 | local step: 157 | global step: 25201 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.186306 | local step: 93 | global step: 25301 | Output: [b'and']
# INFO:tensorflow:Loss: 8.667578 | local step: 28 | global step: 25401 | Output: [b'not']
# INFO:tensorflow:Loss: 1.5904701 | local step: 128 | global step: 25501 | Output: [b'd']
# INFO:tensorflow:Loss: 4.88169 | local step: 75 | global step: 25601 | Output: [b',']
# INFO:tensorflow:Loss: 4.524091 | local step: 6 | global step: 25701 | Output: [b'thou']
# INFO:tensorflow:Loss: 12.8645115 | local step: 106 | global step: 25801 | Output: [b'with']
# INFO:tensorflow:Loss: 7.07445 | local step: 64 | global step: 25901 | Output: [b',']
# INFO:tensorflow:Loss: 6.8676662 | local step: 7 | global step: 26001 | Output: [b'the']
# INFO:tensorflow:Loss: 5.9117928 | local step: 107 | global step: 26101 | Output: [b'thou']
# INFO:tensorflow:Loss: 1.4164758 | local step: 56 | global step: 26201 | Output: [b',']
# INFO:tensorflow:Loss: 0.2870717 | local step: 13 | global step: 26301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.8935056 | local step: 113 | global step: 26401 | Output: [b',']
# INFO:tensorflow:Loss: 11.327029 | local step: 45 | global step: 26501 | Output: [b'the']
# INFO:tensorflow:Loss: 3.5793343 | local step: 145 | global step: 26601 | Output: [b'and']
# INFO:tensorflow:Loss: 1.3504025 | local step: 90 | global step: 26701 | Output: [b's']
# INFO:tensorflow:Loss: 12.760522 | local step: 35 | global step: 26801 | Output: [b',']
# INFO:tensorflow:Loss: 0.17258462 | local step: 135 | global step: 26901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.5709004 | local step: 90 | global step: 27001 | Output: [b'to']
# INFO:tensorflow:Loss: 3.7560525 | local step: 21 | global step: 27101 | Output: [b',']
# INFO:tensorflow:Loss: 7.73242 | local step: 121 | global step: 27201 | Output: [b',']
# INFO:tensorflow:Loss: 7.94115 | local step: 71 | global step: 27301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.5313663 | local step: 1 | global step: 27401 | Output: [b'thou']
# INFO:tensorflow:Loss: 12.650983 | local step: 101 | global step: 27501 | Output: [b',']
# INFO:tensorflow:Loss: 1.0497336 | local step: 42 | global step: 27601 | Output: [b'xxxendxxx']
# INFO:tensorflow:Loss: 4.769706 | local step: 142 | global step: 27701 | Output: [b'i']
# INFO:tensorflow:Loss: 9.343803 | local step: 85 | global step: 27801 | Output: [b'to']
# INFO:tensorflow:Loss: 0.8204208 | local step: 21 | global step: 27901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.328909 | local step: 121 | global step: 28001 | Output: [b'that']
# INFO:tensorflow:Loss: 4.326157 | local step: 80 | global step: 28101 | Output: [b',']
# INFO:tensorflow:Loss: 2.9542482 | local step: 24 | global step: 28201 | Output: [b'of']
# INFO:tensorflow:Loss: 10.761368 | local step: 124 | global step: 28301 | Output: [b',']
# INFO:tensorflow:Loss: 8.219012 | local step: 67 | global step: 28401 | Output: [b'i']
# INFO:tensorflow:Loss: 6.5808296 | local step: 27 | global step: 28501 | Output: [b'and']
# INFO:tensorflow:Loss: 3.117074 | local step: 127 | global step: 28601 | Output: [b'the']
# INFO:tensorflow:Loss: 2.3061562 | local step: 61 | global step: 28701 | Output: [b',']
# INFO:tensorflow:Loss: 3.3820794 | local step: 15 | global step: 28801 | Output: [b',']
# INFO:tensorflow:Loss: 3.4358149 | local step: 115 | global step: 28901 | Output: [b',']
# INFO:tensorflow:Loss: 3.5928905 | local step: 60 | global step: 29001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.1331468 | local step: 14 | global step: 29101 | Output: [b',']
# INFO:tensorflow:Loss: 13.145819 | local step: 114 | global step: 29201 | Output: [b'my']
# INFO:tensorflow:Loss: 7.3113103 | local step: 44 | global step: 29301 | Output: [b',']
# INFO:tensorflow:Loss: 4.466647 | local step: 3 | global step: 29401 | Output: [b',']
# INFO:tensorflow:Loss: 5.602065 | local step: 103 | global step: 29501 | Output: [b',']
# INFO:tensorflow:Loss: 10.226021 | local step: 48 | global step: 29601 | Output: [b'for']
# INFO:tensorflow:Loss: 5.223168 | local step: 1 | global step: 29701 | Output: [b',']
# INFO:tensorflow:Loss: 12.267988 | local step: 101 | global step: 29801 | Output: [b'of']
# INFO:tensorflow:Loss: 3.1376264 | local step: 40 | global step: 29901 | Output: [b'and']
# INFO:tensorflow:Loss: 8.281548 | local step: 140 | global step: 30001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 9.211002 | local step: 83 | global step: 30101 | Output: [b'thy']
# INFO:tensorflow:Loss: 1.2376602 | local step: 26 | global step: 30201 | Output: [b',']
# INFO:tensorflow:Loss: 8.21519 | local step: 126 | global step: 30301 | Output: [b'in']
# INFO:tensorflow:Loss: 8.2120285 | local step: 79 | global step: 30401 | Output: [b"'"]
# INFO:tensorflow:Loss: 7.4770594 | local step: 27 | global step: 30501 | Output: [b'the']
# INFO:tensorflow:Loss: 0.17813545 | local step: 127 | global step: 30601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.9589925 | local step: 75 | global step: 30701 | Output: [b'thou']
# INFO:tensorflow:Loss: 12.921902 | local step: 36 | global step: 30801 | Output: [b',']
# INFO:tensorflow:Loss: 3.4146123 | local step: 136 | global step: 30901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.880788 | local step: 95 | global step: 31001 | Output: [b'my']
# INFO:tensorflow:Loss: 4.6419735 | local step: 46 | global step: 31101 | Output: [b',']
# INFO:tensorflow:Loss: 3.5422082 | local step: 146 | global step: 31201 | Output: [b';']
# INFO:tensorflow:Loss: 5.671996 | local step: 99 | global step: 31301 | Output: [b'for']
# INFO:tensorflow:Loss: 5.8938866 | local step: 37 | global step: 31401 | Output: [b'water']
# INFO:tensorflow:Loss: 6.638209 | local step: 137 | global step: 31501 | Output: [b';']
# INFO:tensorflow:Loss: 15.248929 | local step: 76 | global step: 31601 | Output: [b',']
# INFO:tensorflow:Loss: 3.823763 | local step: 18 | global step: 31701 | Output: [b'.']
# INFO:tensorflow:Loss: 4.0380793 | local step: 118 | global step: 31801 | Output: [b'of']
# INFO:tensorflow:Loss: 6.7985373 | local step: 63 | global step: 31901 | Output: [b"'"]
# INFO:tensorflow:Loss: 2.4086359 | local step: 19 | global step: 32001 | Output: [b"'"]
# INFO:tensorflow:Loss: 13.939227 | local step: 119 | global step: 32101 | Output: [b'that']
# INFO:tensorflow:Loss: 0.79094124 | local step: 72 | global step: 32201 | Output: [b's']
# INFO:tensorflow:Loss: 1.1073114 | local step: 12 | global step: 32301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.1806116 | local step: 112 | global step: 32401 | Output: [b'of']
# INFO:tensorflow:Loss: 5.735244 | local step: 61 | global step: 32501 | Output: [b';']
# INFO:tensorflow:Loss: 7.9940414 | local step: 13 | global step: 32601 | Output: [b'i']
# INFO:tensorflow:Loss: 0.7733685 | local step: 113 | global step: 32701 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.8803515 | local step: 39 | global step: 32801 | Output: [b"'"]
# INFO:tensorflow:Loss: 5.1013255 | local step: 139 | global step: 32901 | Output: [b',']
# INFO:tensorflow:Loss: 9.025595 | local step: 87 | global step: 33001 | Output: [b'moan']
# INFO:tensorflow:Loss: 7.2960434 | local step: 26 | global step: 33101 | Output: [b';']
# INFO:tensorflow:Loss: 3.4392848 | local step: 126 | global step: 33201 | Output: [b',']
# INFO:tensorflow:Loss: 0.12846133 | local step: 65 | global step: 33301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.4340656 | local step: 18 | global step: 33401 | Output: [b',']
# INFO:tensorflow:Loss: 10.543245 | local step: 118 | global step: 33501 | Output: [b';']
# INFO:tensorflow:Loss: 4.2675705 | local step: 60 | global step: 33601 | Output: [b'the']
# INFO:tensorflow:Loss: 6.667369 | local step: 1 | global step: 33701 | Output: [b'thou']
# INFO:tensorflow:Loss: 3.402246 | local step: 101 | global step: 33801 | Output: [b',']
# INFO:tensorflow:Loss: 1.5546068 | local step: 47 | global step: 33901 | Output: [b',']
# INFO:tensorflow:Loss: 1.9799811 | local step: 147 | global step: 34001 | Output: [b',']
# INFO:tensorflow:Loss: 4.7301226 | local step: 88 | global step: 34101 | Output: [b'of']
# INFO:tensorflow:Loss: 9.959304 | local step: 37 | global step: 34201 | Output: [b'art']
# INFO:tensorflow:Loss: 4.103009 | local step: 137 | global step: 34301 | Output: [b',']
# INFO:tensorflow:Loss: 9.094151 | local step: 79 | global step: 34401 | Output: [b'and']
# INFO:tensorflow:Loss: 4.364918 | local step: 10 | global step: 34501 | Output: [b'to']
# INFO:tensorflow:Loss: 2.5091314 | local step: 110 | global step: 34601 | Output: [b'to']
# INFO:tensorflow:Loss: 5.9618273 | local step: 57 | global step: 34701 | Output: [b'of']
# INFO:tensorflow:Loss: 1.9504186 | local step: 8 | global step: 34801 | Output: [b',']
# INFO:tensorflow:Loss: 5.3936377 | local step: 108 | global step: 34901 | Output: [b"'"]
# INFO:tensorflow:Loss: 11.656361 | local step: 55 | global step: 35001 | Output: [b"'"]
# INFO:tensorflow:Loss: 2.8903985 | local step: 6 | global step: 35101 | Output: [b'to']
# INFO:tensorflow:Loss: 8.429553 | local step: 106 | global step: 35201 | Output: [b'such']
# INFO:tensorflow:Loss: 1.1767299 | local step: 56 | global step: 35301 | Output: [b'd']
# INFO:tensorflow:Loss: 6.7080574 | local step: 156 | global step: 35401 | Output: [b',']
# INFO:tensorflow:Loss: 3.5371306 | local step: 98 | global step: 35501 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.0152285 | local step: 29 | global step: 35601 | Output: [b'is']
# INFO:tensorflow:Loss: 4.036517 | local step: 129 | global step: 35701 | Output: [b',']
# INFO:tensorflow:Loss: 13.497364 | local step: 57 | global step: 35801 | Output: [b',']
# INFO:tensorflow:Loss: 2.232304 | local step: 10 | global step: 35901 | Output: [b',']
# INFO:tensorflow:Loss: 5.9386406 | local step: 110 | global step: 36001 | Output: [b'but']
# INFO:tensorflow:Loss: 7.689253 | local step: 59 | global step: 36101 | Output: [b'love']
# INFO:tensorflow:Loss: 5.999937 | local step: 7 | global step: 36201 | Output: [b';']
# INFO:tensorflow:Loss: 9.058183 | local step: 107 | global step: 36301 | Output: [b'the']
# INFO:tensorflow:Loss: 5.824254 | local step: 48 | global step: 36401 | Output: [b',']
# INFO:tensorflow:Loss: 8.9502125 | local step: 148 | global step: 36501 | Output: [b'my']
# INFO:tensorflow:Loss: 4.6266966 | local step: 90 | global step: 36601 | Output: [b'!']
# INFO:tensorflow:Loss: 3.0877526 | local step: 34 | global step: 36701 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.3045619 | local step: 134 | global step: 36801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 15.331646 | local step: 73 | global step: 36901 | Output: [b',']
# INFO:tensorflow:Loss: 15.4509535 | local step: 16 | global step: 37001 | Output: [b'i']
# INFO:tensorflow:Loss: 10.191487 | local step: 116 | global step: 37101 | Output: [b'to']
# INFO:tensorflow:Loss: 5.271159 | local step: 69 | global step: 37201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.5548127 | local step: 10 | global step: 37301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.3215437 | local step: 110 | global step: 37401 | Output: [b'thy']
# INFO:tensorflow:Loss: 4.637438 | local step: 66 | global step: 37501 | Output: [b'of']
# INFO:tensorflow:Loss: 3.0610683 | local step: 8 | global step: 37601 | Output: [b',']
# INFO:tensorflow:Loss: 6.6464076 | local step: 108 | global step: 37701 | Output: [b',']
# INFO:tensorflow:Loss: 6.8772316 | local step: 68 | global step: 37801 | Output: [b'his']
# INFO:tensorflow:Loss: 10.768947 | local step: 19 | global step: 37901 | Output: [b'which']
# INFO:tensorflow:Loss: 0.0038532787 | local step: 119 | global step: 38001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.1868856 | local step: 51 | global step: 38101 | Output: [b',']
# INFO:tensorflow:Loss: 5.406192 | local step: 151 | global step: 38201 | Output: [b'my']
# INFO:tensorflow:Loss: 8.46147 | local step: 91 | global step: 38301 | Output: [b"'"]
# INFO:tensorflow:Loss: 5.184955 | local step: 36 | global step: 38401 | Output: [b"'"]
# INFO:tensorflow:Loss: 1.5234416 | local step: 136 | global step: 38501 | Output: [b',']
# INFO:tensorflow:Loss: 4.0681868 | local step: 93 | global step: 38601 | Output: [b',']
# INFO:tensorflow:Loss: 8.934178 | local step: 31 | global step: 38701 | Output: [b"'"]
# INFO:tensorflow:Loss: 8.789519 | local step: 131 | global step: 38801 | Output: [b'i']
# INFO:tensorflow:Loss: 0.22639069 | local step: 57 | global step: 38901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 6.3788815 | local step: 14 | global step: 39001 | Output: [b'and']
# INFO:tensorflow:Loss: 11.149036 | local step: 114 | global step: 39101 | Output: [b'their']
# INFO:tensorflow:Loss: 2.2129285 | local step: 65 | global step: 39201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.3565903 | local step: 10 | global step: 39301 | Output: [b',']
# INFO:tensorflow:Loss: 4.348895 | local step: 110 | global step: 39401 | Output: [b'and']
# INFO:tensorflow:Loss: 6.813718 | local step: 56 | global step: 39501 | Output: [b'thy']
# INFO:tensorflow:Loss: 0.029746946 | local step: 13 | global step: 39601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.5251102 | local step: 113 | global step: 39701 | Output: [b'more']
# INFO:tensorflow:Loss: 1.7192721 | local step: 57 | global step: 39801 | Output: [b',']
# INFO:tensorflow:Loss: 5.9604044 | local step: 13 | global step: 39901 | Output: [b'of']
# INFO:tensorflow:Loss: 3.306972 | local step: 113 | global step: 40001 | Output: [b'and']
# INFO:tensorflow:Loss: 4.335352 | local step: 57 | global step: 40101 | Output: [b"'"]
# INFO:tensorflow:Loss: 8.618879 | local step: 157 | global step: 40201 | Output: [b';']
# INFO:tensorflow:Loss: 4.380772 | local step: 98 | global step: 40301 | Output: [b"'"]
# INFO:tensorflow:Loss: 2.9663897 | local step: 40 | global step: 40401 | Output: [b'thou']
# INFO:tensorflow:Loss: 4.654251 | local step: 140 | global step: 40501 | Output: [b',']
# INFO:tensorflow:Loss: 5.570015 | local step: 78 | global step: 40601 | Output: [b',']
# INFO:tensorflow:Loss: 8.505921 | local step: 28 | global step: 40701 | Output: [b',']
# INFO:tensorflow:Loss: 0.5232006 | local step: 128 | global step: 40801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 8.171031 | local step: 59 | global step: 40901 | Output: [b',']
# INFO:tensorflow:Loss: 9.041769 | local step: 10 | global step: 41001 | Output: [b'be']
# INFO:tensorflow:Loss: 0.62179077 | local step: 110 | global step: 41101 | Output: [b's']
# INFO:tensorflow:Loss: 2.1428993 | local step: 48 | global step: 41201 | Output: [b',']
# INFO:tensorflow:Loss: 8.091048 | local step: 148 | global step: 41301 | Output: [b',']
# INFO:tensorflow:Loss: 2.7453594 | local step: 85 | global step: 41401 | Output: [b',']
# INFO:tensorflow:Loss: 2.4954598 | local step: 32 | global step: 41501 | Output: [b',']
# INFO:tensorflow:Loss: 0.19743413 | local step: 132 | global step: 41601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.3970811 | local step: 89 | global step: 41701 | Output: [b'that']
# INFO:tensorflow:Loss: 7.492761 | local step: 32 | global step: 41801 | Output: [b',']
# INFO:tensorflow:Loss: 7.3119936 | local step: 132 | global step: 41901 | Output: [b'but']
# INFO:tensorflow:Loss: 3.8505318 | local step: 79 | global step: 42001 | Output: [b',']
# INFO:tensorflow:Loss: 3.3108656 | local step: 15 | global step: 42101 | Output: [b'thy']
# INFO:tensorflow:Loss: 0.26604038 | local step: 115 | global step: 42201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 9.50737 | local step: 66 | global step: 42301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.11543 | local step: 14 | global step: 42401 | Output: [b',']
# INFO:tensorflow:Loss: 11.541315 | local step: 114 | global step: 42501 | Output: [b'in']
# INFO:tensorflow:Loss: 1.6231226 | local step: 72 | global step: 42601 | Output: [b',']
# INFO:tensorflow:Loss: 14.946209 | local step: 19 | global step: 42701 | Output: [b'winter']
# INFO:tensorflow:Loss: 5.8389816 | local step: 119 | global step: 42801 | Output: [b',']
# INFO:tensorflow:Loss: 6.3518114 | local step: 75 | global step: 42901 | Output: [b'and']
# INFO:tensorflow:Loss: 2.6135173 | local step: 15 | global step: 43001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.6337788 | local step: 115 | global step: 43101 | Output: [b'and']
# INFO:tensorflow:Loss: 13.421647 | local step: 77 | global step: 43201 | Output: [b"'"]
# INFO:tensorflow:Loss: 6.699104 | local step: 18 | global step: 43301 | Output: [b'on']
# INFO:tensorflow:Loss: 3.563611 | local step: 118 | global step: 43401 | Output: [b'thy']
# INFO:tensorflow:Loss: 3.2410574 | local step: 65 | global step: 43501 | Output: [b'my']
# INFO:tensorflow:Loss: 5.479536 | local step: 10 | global step: 43601 | Output: [b',']
# INFO:tensorflow:Loss: 2.8800058 | local step: 110 | global step: 43701 | Output: [b',']
# INFO:tensorflow:Loss: 9.002847 | local step: 47 | global step: 43801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.496949 | local step: 147 | global step: 43901 | Output: [b'my']
# INFO:tensorflow:Loss: 9.679765 | local step: 82 | global step: 44001 | Output: [b'in']
# INFO:tensorflow:Loss: 10.309217 | local step: 17 | global step: 44101 | Output: [b'a']
# INFO:tensorflow:Loss: 14.919844 | local step: 117 | global step: 44201 | Output: [b',']
# INFO:tensorflow:Loss: 3.9882398 | local step: 66 | global step: 44301 | Output: [b',']
# INFO:tensorflow:Loss: 3.2829514 | local step: 10 | global step: 44401 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.9172297 | local step: 110 | global step: 44501 | Output: [b'of']
# INFO:tensorflow:Loss: 0.3326327 | local step: 51 | global step: 44601 | Output: [b'd']
# INFO:tensorflow:Loss: 6.4187202 | local step: 151 | global step: 44701 | Output: [b',']
# INFO:tensorflow:Loss: 7.9507537 | local step: 97 | global step: 44801 | Output: [b',']
# INFO:tensorflow:Loss: 4.358259 | local step: 34 | global step: 44901 | Output: [b',']
# INFO:tensorflow:Loss: 4.4203997 | local step: 134 | global step: 45001 | Output: [b'i']
# INFO:tensorflow:Loss: 5.0909743 | local step: 85 | global step: 45101 | Output: [b'in']
# INFO:tensorflow:Loss: 6.6774645 | local step: 22 | global step: 45201 | Output: [b'be']
# INFO:tensorflow:Loss: 3.9997988 | local step: 122 | global step: 45301 | Output: [b',']
# INFO:tensorflow:Loss: 4.408351 | local step: 72 | global step: 45401 | Output: [b'the']
# INFO:tensorflow:Loss: 8.960344 | local step: 8 | global step: 45501 | Output: [b',']
# INFO:tensorflow:Loss: 0.41226697 | local step: 108 | global step: 45601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.079534456 | local step: 56 | global step: 45701 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.3852687 | local step: 13 | global step: 45801 | Output: [b',']
# INFO:tensorflow:Loss: 4.0618157 | local step: 113 | global step: 45901 | Output: [b's']
# INFO:tensorflow:Loss: 4.759454 | local step: 55 | global step: 46001 | Output: [b',']
# INFO:tensorflow:Loss: 1.6700453 | local step: 10 | global step: 46101 | Output: [b',']
# INFO:tensorflow:Loss: 8.154937 | local step: 110 | global step: 46201 | Output: [b'love']
# INFO:tensorflow:Loss: 14.026261 | local step: 58 | global step: 46301 | Output: [b',']
# INFO:tensorflow:Loss: 7.067149 | local step: 21 | global step: 46401 | Output: [b'out']
# INFO:tensorflow:Loss: 13.669642 | local step: 121 | global step: 46501 | Output: [b',']
# INFO:tensorflow:Loss: 3.8724766 | local step: 74 | global step: 46601 | Output: [b',']
# INFO:tensorflow:Loss: 5.9282503 | local step: 39 | global step: 46701 | Output: [b'i']
# INFO:tensorflow:Loss: 0.30987725 | local step: 139 | global step: 46801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 13.631226 | local step: 76 | global step: 46901 | Output: [b',']
# INFO:tensorflow:Loss: 4.406903 | local step: 7 | global step: 47001 | Output: [b',']
# INFO:tensorflow:Loss: 13.516489 | local step: 107 | global step: 47101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.87310326 | local step: 53 | global step: 47201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.063705 | local step: 153 | global step: 47301 | Output: [b',']
# INFO:tensorflow:Loss: 5.6146755 | local step: 97 | global step: 47401 | Output: [b'to']
# INFO:tensorflow:Loss: 3.4071856 | local step: 34 | global step: 47501 | Output: [b',']
# INFO:tensorflow:Loss: 10.357581 | local step: 134 | global step: 47601 | Output: [b"'"]
# INFO:tensorflow:Loss: 0.66277844 | local step: 85 | global step: 47701 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.396236 | local step: 38 | global step: 47801 | Output: [b'love']
# INFO:tensorflow:Loss: 0.30055538 | local step: 138 | global step: 47901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.007397403 | local step: 77 | global step: 48001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.16681343 | local step: 19 | global step: 48101 | Output: [b',']
# INFO:tensorflow:Loss: 2.425759 | local step: 119 | global step: 48201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.5095457 | local step: 58 | global step: 48301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.512181 | local step: 158 | global step: 48401 | Output: [b',']
# INFO:tensorflow:Loss: 9.03465 | local step: 97 | global step: 48501 | Output: [b',']
# INFO:tensorflow:Loss: 2.328171 | local step: 28 | global step: 48601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.4199027 | local step: 128 | global step: 48701 | Output: [b',']
# INFO:tensorflow:Loss: 9.553241 | local step: 65 | global step: 48801 | Output: [b';']
# INFO:tensorflow:Loss: 8.934483 | local step: 16 | global step: 48901 | Output: [b'by']
# INFO:tensorflow:Loss: 0.3174056 | local step: 116 | global step: 49001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 8.209912 | local step: 52 | global step: 49101 | Output: [b'the']
# INFO:tensorflow:Loss: 2.696575 | local step: 5 | global step: 49201 | Output: [b',']
# INFO:tensorflow:Loss: 0.19948933 | local step: 105 | global step: 49301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.6289318 | local step: 36 | global step: 49401 | Output: [b',']
# INFO:tensorflow:Loss: 6.3890586 | local step: 136 | global step: 49501 | Output: [b',']
# INFO:tensorflow:Loss: 0.06233618 | local step: 80 | global step: 49601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.808297 | local step: 8 | global step: 49701 | Output: [b',']
# INFO:tensorflow:Loss: 5.887854 | local step: 108 | global step: 49801 | Output: [b'oppress']
# INFO:tensorflow:Loss: 3.03786 | local step: 49 | global step: 49901 | Output: [b',']
# INFO:tensorflow:Loss: 4.3345523 | local step: 149 | global step: 50001 | Output: [b',']
# INFO:tensorflow:Loss: 11.497148 | local step: 94 | global step: 50101 | Output: [b'the']
# INFO:tensorflow:Loss: 15.549545 | local step: 37 | global step: 50201 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.338251 | local step: 137 | global step: 50301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.8628182 | local step: 74 | global step: 50401 | Output: [b',']
# INFO:tensorflow:Loss: 11.779399 | local step: 27 | global step: 50501 | Output: [b'that']
# INFO:tensorflow:Loss: 3.600401 | local step: 127 | global step: 50601 | Output: [b',']
# INFO:tensorflow:Loss: 3.5292552 | local step: 63 | global step: 50701 | Output: [b',']
# INFO:tensorflow:Loss: 0.17308566 | local step: 18 | global step: 50801 | Output: [b',']
# INFO:tensorflow:Loss: 1.9977357 | local step: 118 | global step: 50901 | Output: [b'your']
# INFO:tensorflow:Loss: 1.2553866 | local step: 75 | global step: 51001 | Output: [b',']
# INFO:tensorflow:Loss: 0.14711718 | local step: 19 | global step: 51101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 8.9824295 | local step: 119 | global step: 51201 | Output: [b'new']
# INFO:tensorflow:Loss: 4.409377 | local step: 75 | global step: 51301 | Output: [b'and']
# INFO:tensorflow:Loss: 4.440905 | local step: 32 | global step: 51401 | Output: [b"'"]
# INFO:tensorflow:Loss: 8.967782 | local step: 132 | global step: 51501 | Output: [b'their']
# INFO:tensorflow:Loss: 2.14396 | local step: 70 | global step: 51601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.6702268 | local step: 11 | global step: 51701 | Output: [b'and']
# INFO:tensorflow:Loss: 5.9650455 | local step: 111 | global step: 51801 | Output: [b'thy']
# INFO:tensorflow:Loss: 2.878258 | local step: 60 | global step: 51901 | Output: [b',']
# INFO:tensorflow:Loss: 1.2516228 | local step: 160 | global step: 52001 | Output: [b'.']
# INFO:tensorflow:Loss: 4.0629797 | local step: 99 | global step: 52101 | Output: [b'give']
# INFO:tensorflow:Loss: 7.4007835 | local step: 36 | global step: 52201 | Output: [b'art']
# INFO:tensorflow:Loss: 11.512503 | local step: 136 | global step: 52301 | Output: [b'i']
# INFO:tensorflow:Loss: 9.799064 | local step: 80 | global step: 52401 | Output: [b'men']
# INFO:tensorflow:Loss: 11.750416 | local step: 33 | global step: 52501 | Output: [b',']
# INFO:tensorflow:Loss: 0.21957895 | local step: 133 | global step: 52601 | Output: [b',']
# INFO:tensorflow:Loss: 9.011071 | local step: 86 | global step: 52701 | Output: [b',']
# INFO:tensorflow:Loss: 2.2972977 | local step: 32 | global step: 52801 | Output: [b',']
# INFO:tensorflow:Loss: 4.6732 | local step: 132 | global step: 52901 | Output: [b',']
# INFO:tensorflow:Loss: 6.285553 | local step: 82 | global step: 53001 | Output: [b',']
# INFO:tensorflow:Loss: 0.0 | local step: 16 | global step: 53101 | Output: [b'of']
# ...
# INFO:tensorflow:Loss: 14.884172 | local step: 48 | global step: 137101 | Output: [b',']
# INFO:tensorflow:Loss: 4.1130695 | local step: 148 | global step: 137201 | Output: [b',']
# INFO:tensorflow:Loss: 2.2855177 | local step: 97 | global step: 137301 | Output: [b'to']
# INFO:tensorflow:Loss: 4.5966253 | local step: 39 | global step: 137401 | Output: [b',']
# INFO:tensorflow:Loss: 9.296423 | local step: 139 | global step: 137501 | Output: [b',']
# INFO:tensorflow:Loss: 2.7322884 | local step: 70 | global step: 137601 | Output: [b"'"]
# INFO:tensorflow:Loss: 1.9707748 | local step: 21 | global step: 137701 | Output: [b"'"]
# INFO:tensorflow:Loss: 5.3774443 | local step: 121 | global step: 137801 | Output: [b'love']
# INFO:tensorflow:Loss: 5.459724 | local step: 56 | global step: 137901 | Output: [b',']
# INFO:tensorflow:Loss: 14.134401 | local step: 156 | global step: 138001 | Output: [b',']
# INFO:tensorflow:Loss: 0.790122 | local step: 95 | global step: 138101 | Output: [b"'"]
# INFO:tensorflow:Loss: 13.688692 | local step: 34 | global step: 138201 | Output: [b"'"]
# INFO:tensorflow:Loss: 1.713572 | local step: 134 | global step: 138301 | Output: [b's']
# INFO:tensorflow:Loss: 3.101171 | local step: 85 | global step: 138401 | Output: [b',']
# INFO:tensorflow:Loss: 0.18507363 | local step: 47 | global step: 138501 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.5197783 | local step: 147 | global step: 138601 | Output: [b',']
# INFO:tensorflow:Loss: 7.9793196 | local step: 83 | global step: 138701 | Output: [b'my']
# INFO:tensorflow:Loss: 7.380765 | local step: 31 | global step: 138801 | Output: [b'love']
# INFO:tensorflow:Loss: 16.77358 | local step: 131 | global step: 138901 | Output: [b'and']
# INFO:tensorflow:Loss: 3.2424428 | local step: 74 | global step: 139001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 1.7639102 | local step: 13 | global step: 139101 | Output: [b"'"]
# INFO:tensorflow:Loss: 4.480846 | local step: 113 | global step: 139201 | Output: [b'in']
# INFO:tensorflow:Loss: 16.356056 | local step: 55 | global step: 139301 | Output: [b',']
# INFO:tensorflow:Loss: 13.936716 | local step: 11 | global step: 139401 | Output: [b'.']
# INFO:tensorflow:Loss: 5.5535507 | local step: 111 | global step: 139501 | Output: [b'thou']
# INFO:tensorflow:Loss: 7.1250525 | local step: 43 | global step: 139601 | Output: [b'i']
# INFO:tensorflow:Loss: 3.8464732 | local step: 143 | global step: 139701 | Output: [b',']
# INFO:tensorflow:Loss: 6.738778 | local step: 97 | global step: 139801 | Output: [b'self']
# INFO:tensorflow:Loss: 14.6874075 | local step: 35 | global step: 139901 | Output: [b'and']
# INFO:tensorflow:Loss: 7.057088 | local step: 135 | global step: 140001 | Output: [b'have']
# INFO:tensorflow:Loss: 6.862133 | local step: 78 | global step: 140101 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.7589846 | local step: 25 | global step: 140201 | Output: [b'thou']
# INFO:tensorflow:Loss: 2.035513 | local step: 125 | global step: 140301 | Output: [b',']
# INFO:tensorflow:Loss: 3.6883059 | local step: 56 | global step: 140401 | Output: [b'but']
# INFO:tensorflow:Loss: 4.4472947 | local step: 9 | global step: 140501 | Output: [b',']
# INFO:tensorflow:Loss: 1.9893166 | local step: 109 | global step: 140601 | Output: [b"'"]
# INFO:tensorflow:Loss: 4.3878365 | local step: 47 | global step: 140701 | Output: [b'the']
# INFO:tensorflow:Loss: 0.6812556 | local step: 147 | global step: 140801 | Output: [b'st']
# INFO:tensorflow:Loss: 2.4398053 | local step: 78 | global step: 140901 | Output: [b',']
# INFO:tensorflow:Loss: 9.003403 | local step: 29 | global step: 141001 | Output: [b'i']
# INFO:tensorflow:Loss: 0.29984948 | local step: 129 | global step: 141101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.2231836 | local step: 66 | global step: 141201 | Output: [b',']
# INFO:tensorflow:Loss: 6.1731834 | local step: 5 | global step: 141301 | Output: [b'my']
# INFO:tensorflow:Loss: 3.725538 | local step: 105 | global step: 141401 | Output: [b',']
# INFO:tensorflow:Loss: 14.026082 | local step: 58 | global step: 141501 | Output: [b'the']
# INFO:tensorflow:Loss: 4.224758 | local step: 6 | global step: 141601 | Output: [b'of']
# INFO:tensorflow:Loss: 11.25632 | local step: 106 | global step: 141701 | Output: [b'not']
# INFO:tensorflow:Loss: 7.606459 | local step: 54 | global step: 141801 | Output: [b',']
# INFO:tensorflow:Loss: 6.053629 | local step: 154 | global step: 141901 | Output: [b',']
# INFO:tensorflow:Loss: 2.2214458 | local step: 97 | global step: 142001 | Output: [b'the']
# INFO:tensorflow:Loss: 10.605898 | local step: 50 | global step: 142101 | Output: [b'my']
# INFO:tensorflow:Loss: 8.848828 | local step: 150 | global step: 142201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.753859 | local step: 82 | global step: 142301 | Output: [b',']
# INFO:tensorflow:Loss: 9.162139 | local step: 39 | global step: 142401 | Output: [b';']
# INFO:tensorflow:Loss: 5.2131977 | local step: 139 | global step: 142501 | Output: [b"'"]
# INFO:tensorflow:Loss: 2.4181988 | local step: 79 | global step: 142601 | Output: [b'i']
# INFO:tensorflow:Loss: 6.146923 | local step: 23 | global step: 142701 | Output: [b'not']
# INFO:tensorflow:Loss: 10.324239 | local step: 123 | global step: 142801 | Output: [b'the']
# INFO:tensorflow:Loss: 8.210994 | local step: 53 | global step: 142901 | Output: [b'with']
# INFO:tensorflow:Loss: 10.346402 | local step: 4 | global step: 143001 | Output: [b'am']
# INFO:tensorflow:Loss: 11.719135 | local step: 104 | global step: 143101 | Output: [b'self']
# INFO:tensorflow:Loss: 2.927875 | local step: 45 | global step: 143201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.29807 | local step: 8 | global step: 143301 | Output: [b';']
# INFO:tensorflow:Loss: 0.05180746 | local step: 108 | global step: 143401 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.1087363 | local step: 56 | global step: 143501 | Output: [b"'"]
# INFO:tensorflow:Loss: 0.15677953 | local step: 9 | global step: 143601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 6.18185 | local step: 109 | global step: 143701 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.102491 | local step: 58 | global step: 143801 | Output: [b'eyes']
# INFO:tensorflow:Loss: 3.9952562 | local step: 158 | global step: 143901 | Output: [b',']
# INFO:tensorflow:Loss: 8.344373 | local step: 99 | global step: 144001 | Output: [b"'"]
# INFO:tensorflow:Loss: 3.9348073 | local step: 40 | global step: 144101 | Output: [b'of']
# INFO:tensorflow:Loss: 3.512416 | local step: 140 | global step: 144201 | Output: [b',']
# INFO:tensorflow:Loss: 6.1925516 | local step: 99 | global step: 144301 | Output: [b'!']
# INFO:tensorflow:Loss: 4.5946546 | local step: 50 | global step: 144401 | Output: [b'this']
# INFO:tensorflow:Loss: 0.5456062 | local step: 150 | global step: 144501 | Output: [b'xxxendxxx']
# INFO:tensorflow:Loss: 0.040009324 | local step: 100 | global step: 144601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.749706 | local step: 42 | global step: 144701 | Output: [b'and']
# INFO:tensorflow:Loss: 7.203549 | local step: 142 | global step: 144801 | Output: [b'heart']
# INFO:tensorflow:Loss: 10.05307 | local step: 93 | global step: 144901 | Output: [b'so']
# INFO:tensorflow:Loss: 7.4716573 | local step: 49 | global step: 145001 | Output: [b'for']
# INFO:tensorflow:Loss: 10.485179 | local step: 149 | global step: 145101 | Output: [b'is']
# INFO:tensorflow:Loss: 9.829901 | local step: 90 | global step: 145201 | Output: [b',']
# INFO:tensorflow:Loss: 16.334007 | local step: 28 | global step: 145301 | Output: [b'for']
# INFO:tensorflow:Loss: 4.3573866 | local step: 128 | global step: 145401 | Output: [b',']
# INFO:tensorflow:Loss: 6.4250975 | local step: 88 | global step: 145501 | Output: [b'self']
# INFO:tensorflow:Loss: 11.259823 | local step: 36 | global step: 145601 | Output: [b',']
# INFO:tensorflow:Loss: 2.262022 | local step: 136 | global step: 145701 | Output: [b',']
# INFO:tensorflow:Loss: 1.3537422 | local step: 81 | global step: 145801 | Output: [b',']
# INFO:tensorflow:Loss: 0.49934772 | local step: 23 | global step: 145901 | Output: [b'and']
# INFO:tensorflow:Loss: 7.2424293 | local step: 123 | global step: 146001 | Output: [b'by']
# INFO:tensorflow:Loss: 6.584079 | local step: 72 | global step: 146101 | Output: [b',']
# INFO:tensorflow:Loss: 5.8877335 | local step: 24 | global step: 146201 | Output: [b'thy']
# INFO:tensorflow:Loss: 8.536105 | local step: 124 | global step: 146301 | Output: [b'fair']
# INFO:tensorflow:Loss: 5.615018 | local step: 72 | global step: 146401 | Output: [b',']
# INFO:tensorflow:Loss: 4.1109705 | local step: 27 | global step: 146501 | Output: [b',']
# INFO:tensorflow:Loss: 8.457457 | local step: 127 | global step: 146601 | Output: [b'shalt']
# INFO:tensorflow:Loss: 4.082574 | local step: 84 | global step: 146701 | Output: [b'name']
# INFO:tensorflow:Loss: 7.164528 | local step: 40 | global step: 146801 | Output: [b'my']
# INFO:tensorflow:Loss: 3.0248446 | local step: 140 | global step: 146901 | Output: [b',']
# INFO:tensorflow:Loss: 5.7121468 | local step: 76 | global step: 147001 | Output: [b'thou']
# INFO:tensorflow:Loss: 17.77486 | local step: 33 | global step: 147101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.2745185 | local step: 133 | global step: 147201 | Output: [b'in']
# INFO:tensorflow:Loss: 11.781439 | local step: 65 | global step: 147301 | Output: [b'not']
# INFO:tensorflow:Loss: 3.0817451 | local step: 13 | global step: 147401 | Output: [b'o']
# INFO:tensorflow:Loss: 8.285084 | local step: 113 | global step: 147501 | Output: [b'i']
# INFO:tensorflow:Loss: 4.7064476 | local step: 43 | global step: 147601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 6.0523043 | local step: 143 | global step: 147701 | Output: [b',']
# INFO:tensorflow:Loss: 4.6080623 | local step: 69 | global step: 147801 | Output: [b'when']
# INFO:tensorflow:Loss: 6.0381536 | local step: 12 | global step: 147901 | Output: [b',']
# INFO:tensorflow:Loss: 7.1776075 | local step: 112 | global step: 148001 | Output: [b'gems']
# INFO:tensorflow:Loss: 15.247456 | local step: 66 | global step: 148101 | Output: [b'be']
# INFO:tensorflow:Loss: 11.242612 | local step: 13 | global step: 148201 | Output: [b'be']
# INFO:tensorflow:Loss: 7.814928 | local step: 113 | global step: 148301 | Output: [b',']
# INFO:tensorflow:Loss: 6.4413366 | local step: 54 | global step: 148401 | Output: [b',']
# INFO:tensorflow:Loss: 8.070063 | local step: 154 | global step: 148501 | Output: [b'off']
# INFO:tensorflow:Loss: 3.9331312 | local step: 99 | global step: 148601 | Output: [b'that']
# INFO:tensorflow:Loss: 5.6472616 | local step: 52 | global step: 148701 | Output: [b'is']
# INFO:tensorflow:Loss: 0.29477042 | local step: 152 | global step: 148801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 11.890448 | local step: 90 | global step: 148901 | Output: [b',']
# INFO:tensorflow:Loss: 15.680707 | local step: 33 | global step: 149001 | Output: [b'me']
# INFO:tensorflow:Loss: 0.048575748 | local step: 133 | global step: 149101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 9.736928 | local step: 75 | global step: 149201 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 14.697867 | local step: 14 | global step: 149301 | Output: [b':']
# INFO:tensorflow:Loss: 4.5834484 | local step: 114 | global step: 149401 | Output: [b'not']
# INFO:tensorflow:Loss: 13.760743 | local step: 60 | global step: 149501 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 10.160802 | local step: 13 | global step: 149601 | Output: [b',']
# INFO:tensorflow:Loss: 2.8085663 | local step: 113 | global step: 149701 | Output: [b'gainst']
# INFO:tensorflow:Loss: 13.10519 | local step: 58 | global step: 149801 | Output: [b'heart']
# INFO:tensorflow:Loss: 5.621976 | local step: 6 | global step: 149901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 10.355825 | local step: 106 | global step: 150001 | Output: [b',']
# INFO:tensorflow:Loss: 9.802962 | local step: 62 | global step: 150101 | Output: [b'and']
# INFO:tensorflow:Loss: 6.6757975 | local step: 19 | global step: 150201 | Output: [b',']
# INFO:tensorflow:Loss: 4.07004 | local step: 119 | global step: 150301 | Output: [b'in']
# INFO:tensorflow:Loss: 5.6031427 | local step: 66 | global step: 150401 | Output: [b'sad']
# INFO:tensorflow:Loss: 11.212046 | local step: 11 | global step: 150501 | Output: [b'world']
# INFO:tensorflow:Loss: 11.038312 | local step: 111 | global step: 150601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 10.145329 | local step: 55 | global step: 150701 | Output: [b"'"]
# INFO:tensorflow:Loss: 0.10327786 | local step: 20 | global step: 150801 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.6376439 | local step: 120 | global step: 150901 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 4.4424353 | local step: 77 | global step: 151001 | Output: [b'the']
# INFO:tensorflow:Loss: 0.2965634 | local step: 19 | global step: 151101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 7.0858502 | local step: 119 | global step: 151201 | Output: [b',']
# INFO:tensorflow:Loss: 8.412587 | local step: 58 | global step: 151301 | Output: [b'melancholy']
# INFO:tensorflow:Loss: 7.699185 | local step: 158 | global step: 151401 | Output: [b'thy']
# INFO:tensorflow:Loss: 0.5113203 | local step: 96 | global step: 151501 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.31463626 | local step: 58 | global step: 151601 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 10.580178 | local step: 6 | global step: 151701 | Output: [b',']
# INFO:tensorflow:Loss: 5.156169 | local step: 106 | global step: 151801 | Output: [b',']
# INFO:tensorflow:Loss: 2.6394413 | local step: 53 | global step: 151901 | Output: [b',']
# INFO:tensorflow:Loss: 3.4325123 | local step: 153 | global step: 152001 | Output: [b',']
# INFO:tensorflow:Loss: 12.03632 | local step: 93 | global step: 152101 | Output: [b'love']
# INFO:tensorflow:Loss: 13.074333 | local step: 44 | global step: 152201 | Output: [b',']
# INFO:tensorflow:Loss: 7.5095444 | local step: 144 | global step: 152301 | Output: [b'heart']
# INFO:tensorflow:Loss: 5.4082394 | local step: 81 | global step: 152401 | Output: [b'and']
# INFO:tensorflow:Loss: 0.6603517 | local step: 34 | global step: 152501 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 3.297052 | local step: 134 | global step: 152601 | Output: [b',']
# INFO:tensorflow:Loss: 4.846326 | local step: 69 | global step: 152701 | Output: [b'a']
# INFO:tensorflow:Loss: 2.2467256 | local step: 6 | global step: 152801 | Output: [b'love']
# INFO:tensorflow:Loss: 1.0034882 | local step: 106 | global step: 152901 | Output: [b',']
# INFO:tensorflow:Loss: 5.6820984 | local step: 41 | global step: 153001 | Output: [b'!']
# INFO:tensorflow:Loss: 6.3243628 | local step: 141 | global step: 153101 | Output: [b'your']
# INFO:tensorflow:Loss: 5.909505 | local step: 84 | global step: 153201 | Output: [b'art']
# INFO:tensorflow:Loss: 6.5231304 | local step: 22 | global step: 153301 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 2.0667367 | local step: 122 | global step: 153401 | Output: [b'thee']
# INFO:tensorflow:Loss: 13.42222 | local step: 67 | global step: 153501 | Output: [b'be']
# INFO:tensorflow:Loss: 6.1957884 | local step: 8 | global step: 153601 | Output: [b'thou']
# INFO:tensorflow:Loss: 6.0228653 | local step: 108 | global step: 153701 | Output: [b'so']
# INFO:tensorflow:Loss: 0.5412964 | local step: 45 | global step: 153801 | Output: [b'of']
# INFO:tensorflow:Loss: 5.454562 | local step: 145 | global step: 153901 | Output: [b'you']
# INFO:tensorflow:Loss: 0.28638333 | local step: 81 | global step: 154001 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 0.42356804 | local step: 37 | global step: 154101 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.2444506 | local step: 137 | global step: 154201 | Output: [b',']
# INFO:tensorflow:Loss: 5.8585434 | local step: 81 | global step: 154301 | Output: [b',']
# INFO:tensorflow:Loss: 8.836505 | local step: 32 | global step: 154401 | Output: [b'xxxnewlinexxx']
# INFO:tensorflow:Loss: 5.7766542 | local step: 132 | global step: 154501 | Output: [b'that']
# Trainning times:  1000

# %% [markdown]
# ## Predict Module

# %%
with tf.variable_scope("model_v1"):
    def pretty(input_str):
        return re.sub("xxxnewlinexxx", "\n", input_str)
    random_word = id2stringtabel.lookup(tf.constant([random.randint(0, 11404)], dtype=tf.int64))
    word_predict, prev_state = sess.run([random_word, out_state], feed_dict={x: np.zeros([1, 50]), state: np.zeros([1, lstm.state_size], dtype=float)})
    print(word_predict)
    poem = [word_predict[0].decode()]
    while word_predict[0].decode() != "xxxendxxx":
        word_predict = sess.run(embed(word_predict))
        word_predict, prev_state = sess.run([word, out_state], feed_dict={x:word_predict, state: prev_state})
        poem.append(word_predict[0].decode())
        tf.logging.log_every_n(tf.logging.INFO, "%s", 20, pretty(" ".join(poem)))
        # print(pretty(" ".join(poem)))
    # Dump to generated dir
    generated_poem = pretty(" ".join(poem))
    filename = "-".join(poem[:5])
    with open("generated/"+filename+".txt", "w") as f:
        f.write(generated_poem)
# Out:
# [b'toe']
# INFO:tensorflow:toe ,
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is '
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth '
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou '
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world '
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world ' s that : ,
#  but you are ,
#  and that bareness should the world and
#  doth not
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world ' s that : ,
#  but you are ,
#  and that bareness should the world and
#  doth not ,
#  and that my love ' s glass ,
#  and you may ,
#  and that thou art
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world ' s that : ,
#  but you are ,
#  and that bareness should the world and
#  doth not ,
#  and that my love ' s glass ,
#  and you may ,
#  and that thou art ' d ,
#  and you to live ,
#  and that my love ,
#  and as a true
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world ' s that : ,
#  but you are ,
#  and that bareness should the world and
#  doth not ,
#  and that my love ' s glass ,
#  and you may ,
#  and that thou art ' d ,
#  and you to live ,
#  and that my love ,
#  and as a true ,
#  and i love ,
#  when that like to i do ' in thy thy love ,
#
# INFO:tensorflow:toe ,
#  and that thou in love , the world of ?
#  that i ' s in the outbraves rais give .
#  i have i not in thee ,
#  and that thou wilt other so ,
#  and to me with a ; ;
#  the the time is of my brow ,
#  and that is ' s besides do , to thee ,
#  and you you ,
#  and in prophetic the mine ,
#  and all my soul ,
#  and with the deserts of every ,
#  that i in my love ,
#  and you in your state , what ;
#  o !
#  but ,
#  and all doth ' d ,
#  and that thou be seek ' s s d and ' d ;
#  to make me
#  to d ,
#  thou you my love , and yet that , and is thy ,
#  and to the prisoner that
#  the thou ,
#  and this quietus your self still ,
#  and all my soul ,
#  and to the with your ,
#  and what is ' d ,
#  that thou ' d love , like ,
#  and to the time of me !
#  in the world doth of love ,
#  and that your self d ,
#
#  the world of lords beauty ,
#  and all my love ,
#  and that thou wilt all me ,
#  and then the love ,
#  ' d ,
#  and that world ' s scope , ' d from you . desperate should ,
#  and all my love ' s glass ,
#  and that but to be vile ,
#  and you , by and love ,
#  and that sweet love ,
#  and that thou be of you ' s i to not ,
#  that my love ,
#  and all my love ,
#  and you in the time ,
#  when i thee ,
#  and that my soul in d to be you ;
#  that in the world ' s that : ,
#  but you are ,
#  and that bareness should the world and
#  doth not ,
#  and that my love ' s glass ,
#  and you may ,
#  and that thou art ' d ,
#  and you to live ,
#  and that my love ,
#  and as a true ,
#  and i love ,
#  when that like to i do ' in thy thy love ,
#  and that my love ,
#  and in thy love love ,
#  and that doth ' s :

# %%
# Write graph to file
writer.close()

# %% [markdown]
# # v1 - Revised
# * Multi-layers of LSTM
#     * Two layers
#     * Both 400 units
# * Non-batch train

# %% [markdown]
# ## Dataset Initialization

# %%
# Dataset
embed = hub.Module("https://tfhub.dev/google/nnlm-en-dim50/1")
string2idtable = tf.contrib.lookup.index_table_from_file(vocabulary_file="vocabulary-shakespeare.txt", num_oov_buckets=0)
id2stringtabel = tf.contrib.lookup.index_to_string_table_from_file(vocabulary_file="vocabulary-shakespeare.txt")
def _insertSpace(sentence):
    sentence = sentence.decode()
    sentence = sentence.lower()
    sentence = re.sub(r'([\W\d])', r' \1 ', sentence)
    return sentence
def _getLabel(sentence):
    splited = tf.string_split([sentence]).values
    sentence = splited
    sentence = sentence[0:-1]
    ids = string2idtable.lookup(splited)
    ids = tf.one_hot(ids, 11405)
    return sentence, ids
filenames = ["poems/shakespeare/sonnets.txt"]
dataset = tf.data.TextLineDataset(filenames)
dataset = dataset.map(lambda sentence: tf.py_func(_insertSpace, [sentence], tf.string))
dataset = dataset.map(_getLabel)
dataset = dataset.shuffle(buffer_size=10000)
# dataset = dataset.batch(4)
dataset = dataset.repeat()
iterator = dataset.make_initializable_iterator()
next_poem = iterator.get_next()

# %% [markdown]
# ## Model initialization and Graph building

# %%
# with tf.Graph().as_default():
# Graph
# Variables
with tf.variable_scope("model_v1_revised", reuse=tf.AUTO_REUSE):
    softmax_w = tf.get_variable("softmax_w", shape=[400, 11405], initializer=tf.random_normal_initializer)
    softmax_b = tf.get_variable("softmax_b", shape=[1, 11405], initializer=tf.random_normal_initializer)

    # TODO Use tuple for state
    lstm = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.LSTMCell(unit, state_is_tuple=False, initializer=tf.random_normal_initializer, reuse=tf.AUTO_REUSE) for unit in [400, 400]], state_is_tuple=False) 

# Model
sentence, label = next_poem
sentence = embed(sentence)
sentence = tf.concat([tf.zeros([1, 50]), sentence], 0, name="Insert_X_0")

state = tf.placeholder(shape=[1, lstm.state_size], dtype=tf.float32, name="Previous_State")

# Input and Label
x = tf.placeholder(shape=[1, 50], dtype=tf.float32, name="Input_Word")
y = tf.placeholder(shape=[1, 11405], dtype=tf.int32, name="Target_Word")

input_word = tf.reshape(x, [1, 50])
output, out_state = lstm(input_word, state)
logits = tf.add(tf.matmul(output, softmax_w), softmax_b)
possibility = tf.nn.softmax(logits=logits, name="Possibilities")
word_index = tf.argmax(possibility, axis=-1, name="Predict_Word_index")
word = id2stringtabel.lookup(word_index)
loss_op = tf.losses.softmax_cross_entropy(onehot_labels=y, logits=logits)
tf.summary.scalar(name="loss", tensor=loss_op)
merged = tf.summary.merge_all()

# Train Ops
with tf.variable_scope("model_v1_revised"):
    optimizer = tf.train.AdamOptimizer()
train_op = optimizer.minimize(loss_op)

# Global step as variable for persistent tensorboard output
# with tf.variable_scope("model_v1"):
#     global_step = tf.get_variable("Global_Steps", [], initializer=tf.ones_initializer, dtype=tf.int64)

# Variables saver
saver = tf.train.Saver()

sess = tf.Session()
# with tf.Session() as sess:
try:
    saver.restore(sess, "tmp/model/model_v1_revised/model.ckpt")
except tf.errors.NotFoundError:
    pass
sess.run(tf.global_variables_initializer())
tf.tables_initializer().run(session=sess)
sess.run(iterator.initializer)

# Trainning log
# TODO writer = tf.summary.FileWriter("tmp/log/"+Modelv1+embedding_version, sess.graph)
writer = tf.summary.FileWriter("tmp/log/model_v1_revised/", sess.graph)

# TODO Retrieve existing g_steps
# g_steps = global_step.eval(session=sess)

g_steps = 1

# %% [markdown]
# ## Train Module

# %%
with tf.variable_scope("model_v1_revised"):
    total_poems = 1000
    for _ in range(total_poems):
        wordsVec, targets = sess.run([sentence, label])
        # TODO How to Access timestep?
        # Initial
        _, pre_state = sess.run([output, out_state], feed_dict={x: [wordsVec[0]], y: [targets[0]], state: np.zeros([1, lstm.state_size], dtype=float)})
        for i in range(1, wordsVec.shape[0]):
            # g_steps = global_step.eval(session=sess)

            _, pre_state, loss, summary, out = sess.run([train_op, out_state, loss_op, merged, word], feed_dict={x: [wordsVec[i]], y: [targets[i]], state: pre_state})
            writer.add_summary(summary, global_step=g_steps)
            # TODO Should Average loss
            tf.logging.log_every_n(tf.logging.INFO, "Loss: %s | local step: %s | global step: %s | Output: %s", 100, loss, i, g_steps, out)
            if g_steps%2000 == 0:
                # Store Variables Every 2000 times
                saver.save(sess, "tmp/model/model_v1_revised/model.ckpt")
            # global_step += 1 
            g_steps += 1
    print("Trainning times: ", total_poems)
    saver.save(sess, "tmp/model/model_v1_revised/model.ckpt")

# %% [markdown]
# ## Predict Module

# %%
with tf.variable_scope("model_v1_revised"):
    def pretty(input_str):
        return re.sub("xxxnewlinexxx", "\n", input_str)
    random_word = id2stringtabel.lookup(tf.constant([random.randint(0, 11404)], dtype=tf.int64))
    word_predict, prev_state = sess.run([random_word, out_state], feed_dict={x: np.zeros([1, 50]), state: np.zeros([1, lstm.state_size], dtype=float)})
    print(word_predict)
    poem = [word_predict[0].decode()]
    while word_predict[0].decode() != "xxxendxxx":
        word_predict = sess.run(embed(word_predict))
        word_predict, prev_state = sess.run([word, out_state], feed_dict={x:word_predict, state: prev_state})
        poem.append(word_predict[0].decode())
        tf.logging.log_every_n(tf.logging.INFO, "%s", 20, pretty(" ".join(poem)))
        # print(pretty(" ".join(poem)))
    # Dump to generated dir
    generated_poem = pretty(" ".join(poem))
    filename = "-".join(poem[:5])
    with open("generated/"+"model_v1_revised_"+filename+".txt", "w") as f:
        f.write(generated_poem)

# %%
# Write graph to file
writer.close()

# %% [markdown]
# # v2 - Multi-RNN with Batch
# * Deep LSTM
#     - Try Different number of layers
#     - Try Different LSTM units amount
# * Unrolled RNNs
#     * [x] Padding
#     * [x] Batch
# * Advanced Sampling
#     * [Candidate Sampling](https://www.tensorflow.org/api_guides/python/nn#Candidate_Sampling)
# * Try other Embedding modules
#     - https://tfhub.dev/google/nnlm-en-dim50/1
#     - https://tfhub.dev/google/nnlm-en-dim50-with-normalization/1
#     - https://tfhub.dev/google/nnlm-en-dim128/1
#     - https://tfhub.dev/google/nnlm-en-dim128-with-normalization/1
#     - https://tfhub.dev/google/Wiki-words-250/1
#     - https://tfhub.dev/google/Wiki-words-250-with-normalization/1
#     - https://tfhub.dev/google/Wiki-words-500/1
#     - https://tfhub.dev/google/Wiki-words-500-with-normalization/1
# * Multi-Dataset for multiple poets
# * Merged Poems Generator
# ## Problem
# * `xxxnewlinexxx` is much more closer, causing low loss value
# * The network then recognize it to be more suitable
# * Same for punctuations

# %%
class machine_poet_v2:
    def __init__(self, embedding_module_url="https://tfhub.dev/google/nnlm-en-dim50/1", embedding_dim=50, lstm_layers_units=(128, 256, 512), batch_size=4, data_filenames=["poems/shakespeare/sonnets.txt"], vocab_filename="vocabulary-shakespeare.txt", vocab_size=11405):
        ##
        # Model Config
        ##
        self.embedding_module_url = embedding_module_url
        self.embedding_dim = embedding_dim
        self.lstm_layers_units = lstm_layers_units
        self.batch_size = batch_size
        # FUTURE For dynamic batch size
        # self.set_batch_size = batch_size
        # self.dynamic_batch_size = batch_size
        # self.data_filenames = data_filenames
        # self.max_length = max_length # Should be the maximum one-line words amount in all data files
        self.vocab_filename = vocab_filename 
        self.vocab_size = vocab_size # Provide vocab_size? or use Tabel.size() method to calculate?
        self.global_steps = 0
        
        ##
        # Identifier
        ##
        # 0 1 2 ~~3~~
        # embedding lstm batch ~~datafile~~
        self.name_list = []
        self.name_list.append("-".join(self.embedding_module_url.split("/")[-2:]))
        self.name_list.append("-".join([ str(i) for i in lstm_layers_units]))
        self.name_list.append(str(batch_size))
        # self.name_list.append("-".join(self.data_filenames[0].split("/")))
        self.id = "-".join(self.name_list) # + str(random.getrandbits(20)) # TODO Add UNQ ID For separating 
        
        ##
        # Initialize Graph for each model instance
        ##
        self.graph = tf.Graph()
        
        with self.graph.as_default():
            ##
            #
            # Data instancs and Data process Ops
            #
            ##
            # Word2Vec Ops
            self.embed_ops = hub.Module(self.embedding_module_url)

            # Vocab lookup tables
            self.string_to_idtable = tf.contrib.lookup.index_table_from_file(vocabulary_file=self.vocab_filename, num_oov_buckets=0)
            self.id_to_stringtabel = tf.contrib.lookup.index_to_string_table_from_file(vocabulary_file=self.vocab_filename)
            
            # Model/Graph Building
            
            with tf.variable_scope("LSTM") as scope:
                # NOTE NO initializer=tf.random_normal_initializer, but WHY?
                # Relu or Tanh?
                cells = [tf.contrib.rnn.LSTMCell(num_units=unit, state_is_tuple=False, initializer=tf.random_normal_initializer) for unit in self.lstm_layers_units]
                # FUTURE state_is_tuple=True
                self.stacked_rnn_cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=False)
                
                # DEBUG ONLY
                # self.stacked_rnn_cell = tf.contrib.rnn.LSTMCell(num_units=64, state_is_tuple=False, initializer=tf.random_normal_initializer)
            
            #####
            # Trainning sub Graph
            #
            # Saved Global Steps
            self.g_steps = tf.get_variable("Global_Steps", [], initializer=tf.zeros_initializer, dtype=tf.int64)
            # Batch_size Max_length Embedding_dim
            # All set None for accommodate dynamic dataset
            # Data
            self.inputs = tf.placeholder(shape=[self.batch_size, None, self.embedding_dim], dtype=tf.float32, name="Input_Words")
            self.inputs_lengths = tf.placeholder(shape=[self.batch_size], dtype=tf.int32, name="Input_Length")
            self.targets = tf.placeholder(shape=[self.batch_size, None, self.vocab_size], dtype=tf.int32, name="Target_Words")
            """
            print(stacked_rnn_cell.state_size)
            state_shape = tf.reshape(stacked_rnn_cell.state_size, [-1])
            state_shape = tf.cast(state_shape, tf.int32)
            print(state_shape)
            state_shape = [tf.Dimension(i) for i in state_shape]
            print(state_shape)
            state_shape = tf.concat([[tf.Dimension(None)], [tf.Dimension(0)]], 0)
            """
            # print(stacked_rnn_cell.state_size)
            
            #[[None, s.c, s.h] for s in stacked_rnn_cell.state_size]
            #state_shape = [len(self.lstm_layers_units), None, s.c, s.h]
            #state_shape = [[None, s.c, s.h] for s in stacked_rnn_cell.state_size]
            #initial_state = tf.placeholder(shape=state_shape, dtype=tf.int32)
            #initial_state=initial_state,
            
            # Unroll the RNN
            outputs, states = tf.nn.dynamic_rnn(cell=self.stacked_rnn_cell, inputs=self.inputs, sequence_length=self.inputs_lengths, dtype=tf.float32)
            # outputs, states = tf.nn.static_rnn(cell=self.stacked_rnn_cell, inputs=self.inputs, sequence_length=self.inputs_lengths, dtype=tf.float32)
            
            # Get logits
            # logits -> shape[batch_size, max_length, vocab_size]
            # TODO Here? Nan?
            # self.Dense = tf.layers.Dense(self.vocab_size, activation=tf.nn.softmax)
            # probabilities = self.Dense(outputs)
            self.Dense = tf.layers.Dense(self.vocab_size)
            logits = self.Dense(outputs)
            
            # Get ouput word
            possibility = tf.nn.softmax(logits)
            word_index = tf.argmax(possibility, axis=-1, name="Predict_Word_index")
            print(word_index.shape)
            self.word_ouput = self.id_to_stringtabel.lookup(word_index)
            print(self.word_ouput.shape)
            
            ##### TODOTODO Loss? Remade
            # Define Loss_Ops
            # Only calculate losses within lengths
            # Modify Loss?
            
            def cost(output, target):
                with tf.name_scope("Cost"):
                    # Compute cross entropy for each frame.
                    # TODO Better MASKING, without casting
                    cross_entropy = tf.multiply(tf.to_float(target), tf.log(output))
                    cross_entropy = -tf.reduce_sum(cross_entropy, 2)

                    mask = tf.to_float(tf.sign(tf.reduce_max(tf.abs(target), 2)))
                    cross_entropy = tf.multiply(cross_entropy, tf.to_float(mask))
                    # Average over actual sequence lengths.
                    cross_entropy = tf.reduce_sum(cross_entropy, 1)
                    cross_entropy /= tf.reduce_sum(mask, 1)
                    return tf.reduce_mean(cross_entropy)
            loss_label = tf.argmax(self.targets, -1)
            self.loss_op = tf.losses.sparse_softmax_cross_entropy(labels=loss_label, logits=logits)
            # self.loss_op = tf.losses.sparse_softmax_cross_entropy(onehot_labels=self.targets, logits=logits)
            # self.loss_op = cost(probabilities, self.targets)
            
            # Define Optimizer_Ops
            optimizer = tf.train.AdamOptimizer()
            # optimizer = tf.train.GradientDescentOptimizer(0.0001)
            # Apply Gradient Clipping to avoid Gradient Exploding
            # gvs = optimizer.compute_gradients(self.loss_op)
            # capped_gvs = [(tf.clip_by_value(grad, -1.0, 1), var) for grad, var in gvs]
            # gvs = [(grad, var) for grad, var in gvs]
            # self.train_op = optimizer.apply_gradientss(gvs)
            self.train_op = optimizer.minimize(self.loss_op) # Unclipped version
            #
            #####
            
            ##
            # Tensorboard Logging
            ##
            # Inputs
            tf.summary.histogram(name="inputs", values=self.inputs)
            tf.summary.histogram(name="inputs_length", values=self.inputs_lengths)
            # Targets
            tf.summary.histogram(name="targets", values=self.targets)
            # Outputs
            tf.summary.histogram(name="Output_possibility", values=possibility)
            # Loss
            tf.summary.scalar(name="loss", tensor=self.loss_op)
            # Log all variables
            for var in tf.trainable_variables():
                print(var.shape)
                self._variable_summaries(var)
            self.merged_op = tf.summary.merge_all()
            
            ##
            # Sampling sub Graph
            ## 
            with tf.name_scope("Sampling"):
                # self.random_start = self.id_to_stringtabel.lookup(tf.constant([random.randint(0, self.vocab_size)], dtype=tf.int64))
                self.initial_state = self.stacked_rnn_cell.zero_state(1, tf.float32)
                self.prev_word = tf.placeholder(shape=[1, self.embedding_dim], dtype=tf.float32, name="Prev_word")
                # print(self.initial_state)
                self.prev_state = tf.placeholder(shape=[1, self.stacked_rnn_cell.state_size], dtype=tf.float32, name="Prev_state")
                
                # print(self.prev_state)
                next_word, self.next_state = self.stacked_rnn_cell(self.prev_word, self.prev_state)
                next_word = self.Dense(next_word)
                next_word = tf.nn.softmax(next_word)
                print("nextword: ", next_word.shape)
                self.next_id = next_word = tf.argmax(tf.reshape(next_word, [-1]))
                print("nextword: ", next_word)
                # Random id
                self.random_start = self.id_to_stringtabel.lookup(tf.constant([random.randint(0, self.vocab_size)], dtype=tf.int64))
                self.next_word = self.id_to_stringtabel.lookup(next_word)
                
    def setDataset(self, data_filenames=["poems/shakespeare/sonnets.txt"], max_length=200, line_slice=None):
        with self.graph.as_default():
            # Loading raw Data
            dataset = tf.data.TextLineDataset(data_filenames)
            ##
            # Preprocess Dataset
            ##
            # Map_fn: Inserting Spaces
            def _insertSpace(sentence):
                sentence = sentence.decode()
                sentence = sentence.lower()
                sentence = re.sub(r'([\W\d])', r' \1 ', sentence)
                return sentence
            # Map_fn: Generating Labels
            def _getLabel(sentence):
                splited = tf.string_split([sentence]).values
                # Limit every input to line_slice words
                splited = splited[:line_slice]
                sentence = splited
                sentence = sentence[0:-1]
                ids = ids_val = self.string_to_idtable.lookup(splited)
                ids = tf.one_hot(ids, self.vocab_size)
                return sentence, ids, ids_val
            
            # Map_fn: Pad Each Sequence, Calculate Length
            # FUTURE Dynamic batch_size? 
            # FUTURE What if batch_size modification occur inside one batch?
            def _padSeq(sentence, ids, ids_val):
                used = tf.sign(tf.abs(ids_val))
                length = tf.reduce_sum(used)
                length = tf.cast(length, tf.int32)
                # Only pad the first dim, which is time_step
                # Shape = [?] with Dtype = tf.string - rank = 1
                sentence = tf.pad(sentence, [[0, max_length-length]], constant_values="")
                # Only pad the first dim, which is time_step
                # Shape = [?, vocab_size] with Dtype = tf.int32 - rank = 2
                ids = tf.pad(ids, [[0, max_length-length], [0, 0]], constant_values=0)
                """
                # FUTURE For dynamic batch size 
                print(length)
                def _pad():    
                    # Padding is needed
                    paddings_config = tf.constant([0, self.max_length-length])
                    sentence = tf.pad(sentence, paddings_config, constant_values="")
                    self.dynamic_batch_size = self.set_batch_size
                def _updateLength():
                    # Set max_length
                    self.max_length = length
                    self.dynamic_batch_size = 1
                tf.cond(length <= self.max_length, true_fn=_pad, false_fn=_updateLength)
                """
                return sentence, ids, length

            dataset = dataset.map(lambda sentence: tf.py_func(_insertSpace, [sentence], tf.string))
            dataset = dataset.map(_getLabel)
            dataset = dataset.map(_padSeq)
            dataset = dataset.shuffle(buffer_size=10000)
            dataset = dataset.apply(tf.contrib.data.batch_and_drop_remainder(self.batch_size))
            dataset = dataset.repeat()
            self.data_iterator = dataset.make_initializable_iterator()
            self.max_length = max_length

    def initialize(self):
        with self.graph.as_default():
            self.saver = tf.train.Saver()
            sess = tf.Session()
            try:
                os.mkdir("tmp/model/" + self.id + "/")
            except FileExistsError:
                pass
            try:
                self.saver.restore(sess, "tmp/model/" + self.id + "/model.ckpt")
            except tf.errors.NotFoundError:
                pass
            sess.run(tf.global_variables_initializer())
            tf.tables_initializer().run(session=sess)
            sess.run(self.data_iterator.initializer)
            self.writer = tf.summary.FileWriter("tmp/log/" + self.id, sess.graph)
            self.session = sess
            
    def train(self, steps):
        with self.graph.as_default():
            sess = self.session
            next_poems = self.data_iterator.get_next()
            # print(sess.run(next_poems))
            # sentence.shape == [Batch_size, max_length, embedding_dim]
            # padding_config.shape == [D, 2]
            padding_config = [[0, 0], [1, 0], [0, 0]]
            self.global_steps = self.g_steps.eval(session=sess)
            print(self.global_steps)
            for step in range(1, steps):
                self.global_steps += 1
                sentences, labels, lengths = sess.run(next_poems)
                # print(sess.run(tf.argmax(labels,-1)))
                sentences = sess.run(tf.pad(tf.reshape(self.embed_ops(tf.reshape(sentences, [-1])), shape=[self.batch_size, self.max_length-1, self.embedding_dim]), padding_config))
                # np.pad
                # Need to tf.pad sentence -> x_0 = O
                #sentence = tf.pad(sentence, )
                _ , loss, summary, wd_out = sess.run([self.train_op, self.loss_op, self.merged_op, self.word_ouput], feed_dict={self.inputs: sentences, self.inputs_lengths: lengths, self.targets: labels})
                # print(wd_out.shape)
                tf.logging.log_every_n(tf.logging.INFO, "Loss: %s | local steps: %s | global steps: %s | Random word in output: %s", 5, loss, step, self.global_steps, wd_out[random.randint(0, self.batch_size-1), random.randint(0, self.max_length-1)])
                if step%5 == 0:
                    self.g_steps.assign(self.global_steps)
                    # text = tf.summary.text("Output_words", tf.cast(wd_out, dtype=tf.string))
                    # self.writer.add_summary(text, global_step=self.global_steps)
                    self.writer.add_summary(summary, global_step=self.global_steps)
                    self.writer.flush()
                    self.saver.save(sess, "tmp/model/" + self.id + "/model.ckpt")
            self.writer.close()
            
    def sampling(self, n_poems):
        with self.graph.as_default():
            sess = self.session
            for poem in range(n_poems):
                initial_state = sess.run(self.initial_state)
                predict_word, pre_state, _id = sess.run([self.random_start, self.next_state, self.next_id], feed_dict={self.prev_word: np.zeros([1, self.embedding_dim]), self.prev_state: initial_state})
                print(_id)
                predict_word = predict_word[0]
                print(predict_word)
                poem = [predict_word.decode()]
                while predict_word.decode() != "xxxendxxx":
                    # Continue Sampling
                    predict_word = sess.run(self.embed_ops([predict_word]))
                    predict_word, pre_state, _id = sess.run([self.next_word, self.next_state, self.next_id], feed_dict={self.prev_word:predict_word, self.prev_state: pre_state})
                    print(_id)
                    poem.append(predict_word.decode())
                    tf.logging.log_every_n(tf.logging.INFO, "%s", 5, self._pretty(" ".join(poem)))
                # Dump to generated dir
                generated_poem = self.pretty(" ".join(poem))
                filename = "-".join(poem[:5])
                with open("generated/"+filename+self.id+".txt", "w") as f:
                    f.write(generated_poem)
                tf.logging.log_every_n(tf.logging.INFO, "Number %s Complete", 1, poem+1)

    
    def _pretty(self, input_str):
        return re.sub("xxxnewlinexxx", "\n", input_str)
    
    def _variable_summaries(self, var):
        """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
        # With Better implementation for dealing invalid name_scope
        with tf.name_scope(''.join(var.name.split(':'))):
            # Lazy
            try:
                mean = tf.reduce_mean(var)
                tf.summary.scalar('mean', mean)
                with tf.name_scope('stddev'):
                    stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
                tf.summary.scalar('stddev', stddev)
                tf.summary.scalar('max', tf.reduce_max(var))
                tf.summary.scalar('min', tf.reduce_min(var))
                tf.summary.histogram('histogram', var)
            except:
                pass

# %%
# def __init__(self, embedding_module_url="https://tfhub.dev/google/nnlm-en-dim50/1", embedding_dim=50, lstm_layers_units=(128, 256, 512), batch_size=4, data_filenames=["poems/shakespeare/sonnets.txt"], max_length=200, vocab_filename="vocabulary-shakespeare.txt", vocab_size=11405):
# model = machine_poet_v2(batch_size=1, max_length=200, lstm_layers_units=(128,))
model = machine_poet_v2(batch_size=4, lstm_layers_units=(16, 16), embedding_module_url="https://tfhub.dev/google/nnlm-en-dim50/1", embedding_dim=50)
model.setDataset(data_filenames=["poems/shakespeare/sonnets-origin.txt", "poems/shakespeare/corpus.txt"], line_slice=None, max_length=10)
model.initialize()

# %%
model.train(100)
# Trainning Problems
# RNN is not learning
# Outputs are all '\n' and 'and'

# %%
model.sampling(1)

# %% [markdown]
# # v2-Revised - Random Output Words
# * Deep LSTM
#     - Try Different number of layers
#     - Try Different LSTM units amount
# * Unrolled RNNs
#     * [x] Padding
#     * [x] Batch
# * Randomly? pick one out of top k element in the output possibility as output word
# * Advanced Sampling
#     * [Candidate Sampling](https://www.tensorflow.org/api_guides/python/nn#Candidate_Sampling)
# * Try other Embedding modules
#     - https://tfhub.dev/google/nnlm-en-dim50/1
#     - https://tfhub.dev/google/nnlm-en-dim50-with-normalization/1
#     - https://tfhub.dev/google/nnlm-en-dim128/1
#     - https://tfhub.dev/google/nnlm-en-dim128-with-normalization/1
#     - https://tfhub.dev/google/Wiki-words-250/1
#     - https://tfhub.dev/google/Wiki-words-250-with-normalization/1
#     - https://tfhub.dev/google/Wiki-words-500/1
#     - https://tfhub.dev/google/Wiki-words-500-with-normalization/1
# * Multi-Dataset for multiple poets
# * Merged Poems Generator
# * TODO
#     * [] Save Global Steps?
# ## Problem
# * `xxxnewlinexxx` is much more closer, causing low loss value
# * The network then recognize it to be more suitable
# * Same for punctuations

# %% [markdown]
# ## Available Configurations Lists

# %%
# Try auto-generate 
# name = "-".join(url.split("/")[-2:])
embedding_modules_list = [
    ("nnlm-en-dim50-1", "https://tfhub.dev/google/nnlm-en-dim50/1"), 
    ("nnlm-en-dim50-with-normalization-1", "https://tfhub.dev/google/nnlm-en-dim50-with-normalization/1"),
    ("nnlm-en-dim128-1", "https://tfhub.dev/google/nnlm-en-dim128/1"),
    ("nnlm-en-dim128-with-normalization-1", "https://tfhub.dev/google/nnlm-en-dim128-with-normalization/1"),
    ("Wiki-words-250-1", "https://tfhub.dev/google/Wiki-words-250/1"),
    ("Wiki-words-250-with-normalization-1", "https://tfhub.dev/google/Wiki-words-250-with-normalization/1"),
    ("Wiki-words-500-1", "https://tfhub.dev/google/Wiki-words-500/1"),
    ("Wiki-words-500-with-normalization-1", "https://tfhub.dev/google/Wiki-words-500-with-normalization/1"),
]

# Auto-generate name for this one
# name = "-".joing(config)
lstm_layers_units_config = [
    (128, 256, 512)
]

# Auto name
batch_sizes = [4, 10, 15]

# Filenames for datasets
# name = "-".join(filenames.split("/"))
trainning_data_filenames = [
    "poems/shakespeare/sonnets.txt"
]

# Filenames for dictionary
vocab_filenames = [
    "vocabulary-shakespeare.txt"
]

# %% [markdown]
# ## Model Class

# %%
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import re
import random
import os

# %%
class machine_poet_v2_revised:
    def __init__(self, embedding_module_url="https://tfhub.dev/google/nnlm-en-dim50/1", embedding_dim=50, lstm_layers_units=(128, 256, 512), learning_rate=0.03, batch_size=4, data_filenames=["poems/shakespeare/sonnets.txt"], max_length=200, vocab_filename="vocabulary-shakespeare.txt", vocab_size=11405):
        ##
        # Model Config
        ##
        self.embedding_module_url = embedding_module_url
        self.embedding_dim = embedding_dim
        self.lstm_layers_units = lstm_layers_units
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        # FUTURE For dynamic batch size
        # self.set_batch_size = batch_size
        # self.dynamic_batch_size = batch_size
        # self.data_filenames = data_filenames
        self.max_length = max_length # Should be the maximum one-line words amount in all data files
        self.vocab_filename = vocab_filename 
        self.vocab_size = vocab_size # Provide vocab_size? or use Tabel.size() method to calculate?
        self.global_steps = 0
        
        ##
        # Identifier
        ##
        # 0 1 2 ~~3~~
        # embedding lstm batch ~~datafile~~
        self.name_list = []
        self.name_list.append("-".join(self.embedding_module_url.split("/")[-2:]))
        self.name_list.append("-".join([ str(i) for i in lstm_layers_units]))
        self.name_list.append("-lr-" + str(self.learning_rate) + "-")
        self.name_list.append(str(batch_size))
        # self.name_list.append("-".join(self.data_filenames[0].split("/")))
        self.id = "-".join(self.name_list) # + str(random.getrandbits(20)) # TODO Add UNQ ID For separating 
        
        ##
        # Initialize Graph for each model instance
        ##
        self.graph = tf.Graph()
        
        with self.graph.as_default():
            ##
            #
            # Data instancs and Data process Ops
            #
            ##
            # Word2Vec Ops
            self.embed_ops = hub.Module(self.embedding_module_url)

            # Vocab lookup tables
            self.string_to_idtable = tf.contrib.lookup.index_table_from_file(vocabulary_file=self.vocab_filename, num_oov_buckets=0)
            self.id_to_stringtabel = tf.contrib.lookup.index_to_string_table_from_file(vocabulary_file=self.vocab_filename)
            
            # Model/Graph Building
            
            with tf.variable_scope("LSTM") as scope:
                # NOTE NO initializer=tf.random_normal_initializer, but WHY?
                # Relu or Tanh?
                cells = [tf.contrib.rnn.LSTMCell(num_units=unit, state_is_tuple=False, initializer=tf.random_normal_initializer) for unit in self.lstm_layers_units]
                # FUTURE state_is_tuple=True
                self.stacked_rnn_cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=False)
                
                # DEBUG ONLY
                # self.stacked_rnn_cell = tf.contrib.rnn.LSTMCell(num_units=64, state_is_tuple=False, initializer=tf.random_normal_initializer)
            
            #####
            # Trainning sub Graph
            #
            # Saved Global Steps
            self.g_steps = tf.get_variable("Global_Steps", [], initializer=tf.zeros_initializer, dtype=tf.int64)
            # Batch_size Max_length Embedding_dim
            # All set None for accommodate dynamic dataset
            # Data
            self.inputs = tf.placeholder(shape=[self.batch_size, self.max_length, self.embedding_dim], dtype=tf.float32, name="Input_Words")
            self.inputs_lengths = tf.placeholder(shape=[self.batch_size], dtype=tf.int32, name="Input_Length")
            self.targets = tf.placeholder(shape=[self.batch_size, self.max_length, self.vocab_size], dtype=tf.int32, name="Target_Words")
            """
            print(stacked_rnn_cell.state_size)
            state_shape = tf.reshape(stacked_rnn_cell.state_size, [-1])
            state_shape = tf.cast(state_shape, tf.int32)
            print(state_shape)
            state_shape = [tf.Dimension(i) for i in state_shape]
            print(state_shape)
            state_shape = tf.concat([[tf.Dimension(None)], [tf.Dimension(0)]], 0)
            """
            # print(stacked_rnn_cell.state_size)
            
            #[[None, s.c, s.h] for s in stacked_rnn_cell.state_size]
            #state_shape = [len(self.lstm_layers_units), None, s.c, s.h]
            #state_shape = [[None, s.c, s.h] for s in stacked_rnn_cell.state_size]
            #initial_state = tf.placeholder(shape=state_shape, dtype=tf.int32)
            #initial_state=initial_state,
            
            # Unroll the RNN
            outputs, states = tf.nn.dynamic_rnn(cell=self.stacked_rnn_cell, inputs=self.inputs, sequence_length=self.inputs_lengths, dtype=tf.float32)
            # outputs, states = tf.nn.static_rnn(cell=self.stacked_rnn_cell, inputs=self.inputs, sequence_length=self.inputs_lengths, dtype=tf.float32)
            
            # Get logits
            # logits -> shape[batch_size, max_length, vocab_size]
            # TODO Here? Nan?
            # self.Dense = tf.layers.Dense(self.vocab_size, activation=tf.nn.softmax)
            # probabilities = self.Dense(outputs)
            self.Dense = tf.layers.Dense(self.vocab_size)
            logits = self.Dense(outputs)
            
            # Get ouput word
            possibility = tf.nn.softmax(logits)
            
            word_index = tf.argmax(possibility, axis=-1, name="Predict_Word_index")
            # [barch_size, max_length, k]
            # Input should be a list
            # [batch_size, max_length, k]
            # Randomly Pick 1 out of N classes 
            #_, word_index = tf.nn.top_k(possibility, k=4, sorted=False, name="K_Predict_Word_Index")
            # word_index = word_index[:, :, 0]
            # word_index = tf.cast(word_index, dtype=tf.int64)
            print(word_index.shape)
            self.word_ouput = self.id_to_stringtabel.lookup(word_index)
            print(self.word_ouput.shape)
            
            ##### TODOTODO Loss? Remade
            # Define Loss_Ops
            # Only calculate losses within lengths
            # Modify Loss?
            
            def cost(output, target):
                with tf.name_scope("Cost"):
                    # Compute cross entropy for each frame.
                    # TODO Better MASKING, without casting
                    cross_entropy = tf.multiply(tf.to_float(target), tf.log(output))
                    cross_entropy = -tf.reduce_sum(cross_entropy, 2)

                    mask = tf.to_float(tf.sign(tf.reduce_max(tf.abs(target), 2)))
                    cross_entropy = tf.multiply(cross_entropy, tf.to_float(mask))
                    # Average over actual sequence lengths.
                    cross_entropy = tf.reduce_sum(cross_entropy, 1)
                    cross_entropy /= tf.reduce_sum(mask, 1)
                    return tf.reduce_mean(cross_entropy)
            loss_label = tf.argmax(self.targets, -1)
            self.loss_op = tf.losses.sparse_softmax_cross_entropy(labels=loss_label, logits=logits)
            # self.loss_op = tf.losses.sparse_softmax_cross_entropy(onehot_labels=self.targets, logits=logits)
            # self.loss_op = cost(probabilities, self.targets)
            
            # Define Optimizer_Ops
            optimizer = tf.train.AdamOptimizer(self.learning_rate)
            # optimizer = tf.train.GradientDescentOptimizer(0.0001)
            # Apply Gradient Clipping to avoid Gradient Exploding
            # gvs = optimizer.compute_gradients(self.loss_op)
            # capped_gvs = [(tf.clip_by_value(grad, -1.0, 1), var) for grad, var in gvs]
            # gvs = [(grad, var) for grad, var in gvs]
            # self.train_op = optimizer.apply_gradientss(gvs)
            self.train_op = optimizer.minimize(self.loss_op) # Unclipped version
            #
            #####
            
            ##
            # Tensorboard Logging
            ##
            # Inputs
            tf.summary.histogram(name="inputs", values=self.inputs)
            tf.summary.histogram(name="inputs_length", values=self.inputs_lengths)
            # Targets
            tf.summary.histogram(name="targets", values=self.targets)
            # Outputs
            tf.summary.histogram(name="Output_possibility", values=possibility)
            # Loss
            tf.summary.scalar(name="loss", tensor=self.loss_op)
            # Log all variables
            for var in tf.trainable_variables():
                print(var.shape)
                self._variable_summaries(var)
            self.merged_op = tf.summary.merge_all()
            
            ##
            # Sampling sub Graph
            ## 
            with tf.name_scope("Sampling"):
                # self.random_start = self.id_to_stringtabel.lookup(tf.constant([random.randint(0, self.vocab_size)], dtype=tf.int64))
                self.initial_state = self.stacked_rnn_cell.zero_state(1, tf.float32)
                self.prev_word = tf.placeholder(shape=[1, self.embedding_dim], dtype=tf.float32, name="Prev_word")
                # print(self.initial_state)
                self.prev_state = tf.placeholder(shape=[1, self.stacked_rnn_cell.state_size], dtype=tf.float32, name="Prev_state")
                
                # print(self.prev_state)
                next_word, self.next_state = self.stacked_rnn_cell(self.prev_word, self.prev_state)
                next_word = self.Dense(next_word)
                next_word = tf.nn.softmax(next_word)
                print("nextword: ", next_word.shape)
                self.next_id = next_word = tf.argmax(tf.reshape(next_word, [-1]))
                print("nextword: ", next_word)
                # Random id
                self.random_start = self.id_to_stringtabel.lookup(tf.constant([random.randint(0, self.vocab_size)], dtype=tf.int64))
                self.next_word = self.id_to_stringtabel.lookup(next_word)
                
    def setDataset(self, data_filenames=["poems/shakespeare/sonnets.txt"]):
        with self.graph.as_default():
            # Loading raw Data
            dataset = tf.data.TextLineDataset(data_filenames)
            ##
            # Preprocess Dataset
            ##
            # Map_fn: Inserting Spaces
            def _insertSpace(sentence):
                sentence = sentence.decode()
                sentence = sentence.lower()
                sentence = re.sub(r'([\W\d])', r' \1 ', sentence)
                return sentence
            # Map_fn: Generating Labels
            def _getLabel(sentence):
                splited = tf.string_split([sentence]).values
                # Limit every input to line_slice words
                # splited = splited[:30]
                sentence = splited
                sentence = sentence[0:-1]
                ids = ids_val = self.string_to_idtable.lookup(splited)
                ids = tf.one_hot(ids, self.vocab_size)
                return sentence, ids, ids_val
            
            # Map_fn: Pad Each Sequence, Calculate Length
            # FUTURE Dynamic batch_size? 
            # FUTURE What if batch_size modification occur inside one batch?
            def _padSeq(sentence, ids, ids_val):
                used = tf.sign(tf.abs(ids_val))
                length = tf.reduce_sum(used)
                length = tf.cast(length, tf.int32)
                # Only pad the first dim, which is time_step
                # Shape = [?] with Dtype = tf.string - rank = 1
                sentence = tf.pad(sentence, [[0, self.max_length-length]], constant_values="")
                # Only pad the first dim, which is time_step
                # Shape = [?, vocab_size] with Dtype = tf.int32 - rank = 2
                ids = tf.pad(ids, [[0, self.max_length-length], [0, 0]], constant_values=0)
                """
                # FUTURE For dynamic batch size 
                print(length)
                def _pad():    
                    # Padding is needed
                    paddings_config = tf.constant([0, self.max_length-length])
                    sentence = tf.pad(sentence, paddings_config, constant_values="")
                    self.dynamic_batch_size = self.set_batch_size
                def _updateLength():
                    # Set max_length
                    self.max_length = length
                    self.dynamic_batch_size = 1
                tf.cond(length <= self.max_length, true_fn=_pad, false_fn=_updateLength)
                """
                return sentence, ids, length

            dataset = dataset.map(lambda sentence: tf.py_func(_insertSpace, [sentence], tf.string))
            dataset = dataset.map(_getLabel)
            dataset = dataset.map(_padSeq)
            dataset = dataset.shuffle(buffer_size=10000)
            dataset = dataset.apply(tf.contrib.data.batch_and_drop_remainder(self.batch_size))
            dataset = dataset.repeat()
            self.data_iterator = dataset.make_initializable_iterator()

    def initialize(self):
        with self.graph.as_default():
            self.saver = tf.train.Saver()
            sess = tf.Session()
            try:
                os.mkdir("tmp/model/" + self.id + "/")
            except FileExistsError:
                pass
            try:
                self.saver.restore(sess, "tmp/model/" + self.id + "/model.ckpt")
            except tf.errors.NotFoundError:
                pass
            sess.run(tf.global_variables_initializer())
            tf.tables_initializer().run(session=sess)
            sess.run(self.data_iterator.initializer)
            self.writer = tf.summary.FileWriter("tmp/log/" + self.id, sess.graph)
            self.session = sess
            
    def train(self, steps):
        with self.graph.as_default():
            sess = self.session
            next_poems = self.data_iterator.get_next()
            # print(sess.run(next_poems))
            # sentence.shape == [Batch_size, max_length, embedding_dim]
            # padding_config.shape == [D, 2]
            padding_config = [[0, 0], [1, 0], [0, 0]]
            # self.global_steps = self.g_steps.eval(session=sess)
            print(self.global_steps)
            for step in range(1, steps):
                self.global_steps += 1
                sentences, labels, lengths = sess.run(next_poems)
                # print(sess.run(tf.argmax(labels,-1)))
                sentences = sess.run(tf.pad(tf.reshape(self.embed_ops(tf.reshape(sentences, [-1])), shape=[self.batch_size, self.max_length-1, self.embedding_dim]), padding_config))
                # np.pad
                # Need to tf.pad sentence -> x_0 = O
                #sentence = tf.pad(sentence, )
                _ , loss, summary, wd_out = sess.run([self.train_op, self.loss_op, self.merged_op, self.word_ouput], feed_dict={self.inputs: sentences, self.inputs_lengths: lengths, self.targets: labels})
                tf.logging.log_every_n(tf.logging.INFO, "Loss: %s | local steps: %s | global steps: %s | Random word in output: %s", 10, loss, step, self.global_steps, wd_out[random.randint(0, self.batch_size-1), random.randint(0, self.max_length-1)])
                if step%10 == 1:
                    # self.g_steps.assign(self.global_steps)
                    # text = tf.summary.text("Output_words", tf.cast(wd_out, dtype=tf.string))
                    # self.writer.add_summary(text, global_step=self.global_steps)
                    self.writer.add_summary(summary, global_step=self.global_steps)
                    self.writer.flush()
                    self.saver.save(sess, "tmp/model/" + self.id + "/model.ckpt")
            self.writer.close()
            
    def sampling(self, n_poems, input_word=None):
        with self.graph.as_default():
            sess = self.session
            initial_state = sess.run(self.initial_state)
            # TODO Condition expression
            predict_word, pre_state, _id = sess.run([self.random_start, self.next_state, self.next_id], feed_dict={self.prev_word: np.zeros([1, self.embedding_dim]), self.prev_state: initial_state})
            if input_word != None:
                predict_word = [input_word.encode()]
            print(_id)
            predict_word = predict_word[0]
            print(predict_word)
            poem = [predict_word.decode()]
            while predict_word.decode() != "xxxendxxx":
                # Continue Sampling
                predict_word = sess.run(self.embed_ops([predict_word]))
                predict_word, pre_state, _id = sess.run([self.next_word, self.next_state, self.next_id], feed_dict={self.prev_word:predict_word, self.prev_state: pre_state})
                print(_id)
                poem.append(predict_word.decode())
                tf.logging.log_every_n(tf.logging.INFO, "%s", 5, self._pretty(" ".join(poem)))
            # Dump to generated dir
            generated_poem = self.pretty(" ".join(poem))
            filename = "-".join(poem[:5])
            with open("generated/"+filename+self.id+".txt", "w") as f:
                f.write(generated_poem)

    
    def _pretty(self, input_str):
        return re.sub("xxxnewlinexxx", "\n", input_str)
    
    def _variable_summaries(self, var):
        """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
        # With Better implementation for dealing invalid name_scope
        with tf.name_scope(''.join(var.name.split(':'))):
            # Lazy
            try:
                mean = tf.reduce_mean(var)
                tf.summary.scalar('mean', mean)
                with tf.name_scope('stddev'):
                    stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
                tf.summary.scalar('stddev', stddev)
                tf.summary.scalar('max', tf.reduce_max(var))
                tf.summary.scalar('min', tf.reduce_min(var))
                tf.summary.histogram('histogram', var)
            except:
                pass

# %%
# def __init__(self, embedding_module_url="https://tfhub.dev/google/nnlm-en-dim50/1", embedding_dim=50, lstm_layers_units=(128, 256, 512), batch_size=4, data_filenames=["poems/shakespeare/sonnets.txt"], max_length=200, vocab_filename="vocabulary-shakespeare.txt", vocab_size=11378):
model = machine_poet_v2_revised(learning_rate=0.03,batch_size=32, lstm_layers_units=(32, 32), embedding_module_url="https://tfhub.dev/google/Wiki-words-250/1", embedding_dim=250)
model.setDataset()
model.initialize()

# %%
model.train(100)
# Trainning Problems
# RNN is not learning
# Outputs are all '\n' and 'and'

# %%
model.sampling(1, input_word="thy")

# %% [markdown]
# # v3 - Dropout Multi Graphs
